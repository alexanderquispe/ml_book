# %% [markdown]
# # Chapter 2 Introduction to Machine Learning

# %% [markdown]
# In this chapter, we’ll briefly review machine learning concepts that will be relevant later. We’ll focus in particular on the problem of prediction, that is, to model some output variable as a function of observed input covariates.

# %%
# importing the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import math
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# In this section, we will use simulated data. In the next section we’ll load a real dataset.

# %%
n = 500 #number of observations
x = np.linspace(-4,4, n) #with linspace we can generate a vector of "n" numbers between a range of numbers

random.shuffle(x) 
mu = np.where(x<0,np.cos(2*x) + np.random.rand(n), 1 + np.sin(x) + np.random.rand(n) )

y = mu + 1*np.random.rand(n) 

data = pd.DataFrame(np.array([x,y]).T, columns=['x','y'])

plt.figure(figsize=(18,6))
sns.scatterplot(x,y, color = 'red', label = 'Data')
sns.lineplot(x,mu, color = 'black', label = "Ground truth E[Y|X=x]")
plt.legend()
plt.xlabel("X")
plt.ylabel("Outcome y")
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# Note: If you’d like to run the code below on a different dataset, you can replace the dataset above with another `data.frame` of your choice, and redefine the key variable identifiers (`outcome`, `covariates`) accordingly. Although we try to make the code as general as possible, you may also need to make a few minor changes to the code below; read the comments carefully.

# %% [markdown]
# ## 2.1 Key concepts

# %% [markdown]
# The prediction problem is to accurately guess the value of some output variable $Y_i$ from input variables $X_i$. For example, we might want to predict “house prices given house characteristics such as the number of rooms, age of the building, and so on. The relationship between input and output is modeled in very general terms by some function
# \begin{equation}
#
#   Y_i = f(X_i) + \epsilon_i
# \end{equation}
# where $\epsilon_i$ represents all that is not captured by information obtained from $X_i$ via the mapping $f$. We say that error $\epsilon_i$ is irreducible.
#
# We highlight that \@ref(eq:true-model) is **not modeling a causal relationship** between inputs and outputs. For an extreme example, consider taking $Y_i$ to be “distance from the equator” and $X_i$ to be “average temperature.” We can still think of the problem of guessing (“predicting”) “distance from the equator” given some information about “average temperature,” even though one would expect the former to cause the latter.
#
# In general, we can’t know the “ground truth”  $f$, so we will approximate it from data. Given $n$ data points $\{(X_1, Y_1), \cdots, (X_n, Y_n)\}$, our goal is to obtain an estimated model  $\hat{f}$ such that our predictions $\widehat{Y}_i := \hat{f}(X_i)$ are “close” to the true outcome values $Y_i$ given some criterion. To formalize this, we’ll follow these three steps:
#
# + **Modeling:** Decide on some suitable class of functions that our estimated model may belong to. In machine learning applications the class of functions can be very large and complex (e.g., deep decision trees, forests, high-dimensional linear models, etc). Also, we must decide on a loss function that serves as our criterion to evaluate the quality of our predictions (e.g., mean-squared error).
#
# + **Fitting:** Find the estimate $\hat{f}$ that optimizes the loss function chosen in the previous step (e.g., the tree that minimizes the squared deviation between $\hat{f}(X_i)$ and $Y_i$ in our data).
#
# + **Evaluation:** Evaluate our fitted model $\hat{f}$. That is, if we were given a new, yet unseen, input and output pair $(X',Y')$, we'd like to know if $Y' \approx \hat{f}(X_i)$ by some metric.
#
# For concreteness, let’s work through an example. Let’s say that, given the data simulated above, we’d like to predict $Y_i$ from the first covariate  $X_{i1}$ only. Also, let’s say that our model class will be polynomials of degree $q$ in $X_{i1}$, and we’ll evaluate fit based on mean squared error. That is, $\hat{f}(X_{i1}) = \hat{b}_0 + X_{i1}\hat{b}_1 + \cdots + X_{i1}^q \hat{b}_q$, where the coefficients are obtained by solving the following problem:
# \begin{equation}
#   \hat{b} = \arg\min_b \sum_{i=1}^m
#     \left(Y_i - b_0 - X_{i1}b_1 - \cdots - X_{iq}^q b_q \right)^2
# \end{equation}
# An important question is what is $q$, the degree of the polynomial. It controls the complexity of the model. One may imagine that more complex models are better, but that is not always true, because a very flexible model may try to simply interpolate over the data at hand, but fail to generalize well for new data points. We call this **overfitting**. The main feature of overfitting is **high variance**, in the sense that, if we were given a different data set of the same size, we'd likely get a very different model.
#
# To illustrate, in the figure below we let the degree be  $q=10$ but use only the first few data points. The fitted model is shown in green, and the original data points are in red.

# %%
X = data.loc[:,'x'].values.reshape(-1, 1)
Y = data.loc[:,'y'].values.reshape(-1, 1)


subset = np.arange(0,30)
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split


poly = PolynomialFeatures(degree = 10)
X_poly = poly.fit_transform(X)

poly.fit(X_poly, Y)
lin2 = LinearRegression()
lin2.fit(X_poly[0:30], Y[0:30])

x = data['x']
xgrid = np.linspace(min(x),max(x), 1000)

new_data = pd.DataFrame(xgrid, columns=['x'])

yhat = lin2.predict(poly.fit_transform(new_data))

# Visualising the Polynomial Regression results
plt.figure(figsize=(18,6))
sns.scatterplot(data.loc[subset,'x'],data.loc[subset,'y'], color = 'red', label = 'Data')
plt.plot(xgrid, yhat, color = 'green', label = 'Estimate')
plt.title('Example of overfitting')
plt.xlabel('X')
plt.ylabel('Outcome y')
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# On the other hand, when $q$ is too small relative to our data, we permit only very simple models and may suffer from misspecification bias. We call this **underfitting**. The main feature of underfitting is **high bias** -- the selected model just isn't complex enough to accurately capture the relationship between input and output variables.
#
# To illustrate underfitting, in the figure below we set $q=1$ (a linear fit).

# %%
lin = LinearRegression()

lin.fit(X[0:30], Y[0:30])


x = data['x']
xgrid = np.linspace(min(x),max(x), 1000)

new_data = pd.DataFrame(xgrid, columns=['x'])

yhat = lin.predict(new_data)

plt.figure(figsize=(18,6))
sns.scatterplot(data.loc[subset,'x'],data.loc[subset,'y'], color = 'red', label = 'Data')
plt.plot(xgrid, yhat, color = 'green',label = 'Estimate')
plt.title('Example of underfitting')
plt.xlabel('X')
plt.ylabel('Outcome y')
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# This tension is called the **bias-variance trade-off**: simpler models underfit and have more bias, more complex models overfit and have more variance.
#
# One data-driven way of deciding an appropriate level of complexity is to divide the available data into a training set (where the model is fit) and the validation set (where the model is evaluated). The next snippet of code uses the first half of the data to fit a polynomial of order $q$, and then evaluates that polynomial on the second half. The training MSE estimate decreases monotonically with the polynomial degree, because the model is better able to fit on the training data; the test MSE estimate starts increasing after a while reflecting that the model no longer generalizes well.

# %%
degrees =np.arange(3,21)
train_mse =[]
test_mse =[]
for d in degrees:
    poly =PolynomialFeatures(degree = d, include_bias =False  )
    poly_features = poly.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(poly_features,y, train_size=0.5, random_state=0)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# we have to define valid_size=0.5 (that is 50% of remaining data)

    poly_reg_model = LinearRegression()
    poly_reg_model.fit(X_train, y_train)
    

    
    y_train_pred = poly_reg_model.predict(X_train)
    y_test_pred = poly_reg_model.predict(X_test)

    mse_train= mean_squared_error(y_train, y_train_pred)
    mse_test= mean_squared_error(y_test, y_test_pred)
    
    train_mse.append(mse_train)
    test_mse.append(mse_test)

# %%
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(degrees, train_mse,color ="black", label = "Training")
ax.plot(degrees, test_mse,"r--", label = "Validation")
ax.set_title("MSE Estimates (train test split)", fontsize =14)
ax.set(xlabel = "Polynomial degree", ylabel = "MSE estimate")
ax.annotate("Low bias \n High Variance", xy=(19, 0.23), xycoords='data', xytext=(16, 0.23), textcoords='data',
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3"),)
ax.annotate("High bias \n Low Variance", xy=(5.3, 0.37), xycoords='data', xytext=(7, 0.37), textcoords='data',
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3"),)
# Out:
# Text(7, 0.37, 'High bias \n Low Variance')

# %% [markdown]
# To make better use of the data we will often divide the data into $K$ subsets, or _folds_. Then one fits $K$ models, each using  $K-1$ folds and then evaluation the fitted model on the remaining fold. This is called **k-fold cross-validation**.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
#cv = KFold(n_splits=10, random_state=1, shuffle=True)
scorer = make_scorer
mse =[]

for d in degrees: 
    
    poly =PolynomialFeatures(degree = d, include_bias =False  )
    poly_features = poly.fit_transform(X)
    ols = LinearRegression()
    scorer = make_scorer(mean_squared_error)
    mse_test= cross_val_score(ols, poly_features, y, scoring=scorer, cv =10).mean()
    mse.append(mse_test)

# %%
plt.figure(figsize=(18,6))
plt.plot(degrees, mse)
plt.xlabel('Polynomial degree', fontsize = 14)
plt.ylabel('MSE estimate', fontsize = 14)
plt.title('MSE estimate (K-fold cross validation)', fontsize =16)
#different to r, the models in python got a better performance with more training cause by the
#cross validation and the kfold
# Out:
# Text(0.5, 1.0, 'MSE estimate (K-fold cross validation)')

# %% [markdown]
# A final remark is that, in machine learning applications, the complexity of the model often is allowed to increase with the available data. In the example above, even though we weren’t very successful when fitting a high-dimensional model on very little data, if we had much more data perhaps such a model would be appropriate. The next figure again fits a high order polynomial model, but this time on many data points. Note how, at least in data-rich regions, the model is much better behaved, and tracks the average outcome reasonably well without trying to interpolate wildly of the data points.

# %%
X = data.loc[:,'x'].values.reshape(-1, 1)
Y = data.loc[:,'y'].values.reshape(-1, 1)


subset = np.arange(0,500)

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures


poly = PolynomialFeatures(degree = 15)
X_poly = poly.fit_transform(X)

poly.fit(X_poly, Y)
lin2 = LinearRegression()
lin2.fit(X_poly[0:500], Y[0:500])

x = data['x']
xgrid = np.linspace(min(x),max(x), 1000)

new_data = pd.DataFrame(xgrid, columns=['x'])

yhat = lin2.predict(poly.fit_transform(new_data))

# Visualising the Polynomial Regression results
plt.figure(figsize=(18,6))
sns.scatterplot(data.loc[subset,'x'],data.loc[subset,'y'], color = 'red', label = 'Data')
plt.plot(xgrid, yhat, color = 'green', label = 'Estimate')
sns.lineplot(x,mu, color = 'black', label = "Ground truth E[Y|X=x]")

plt.title('Example of overfitting')
plt.xlabel('X')
plt.ylabel('Outcome y')
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# This is one of the benefits of using machine learning-based models: more data implies more flexible modeling, and therefore potentially better predictive power -- provided that we carefully avoid overfitting.
#
# The example above based on polynomial regression was used mostly for illustration. In practice, there are often better-performing algorithms. We’ll see some of them next.

# %% [markdown]
# ## 2.2 Common machine learning algorithms

# %% [markdown]
# Next, we’ll introduce three machine learning algorithms: (regularized) linear models, trees, and forests. Although this isn't an exhaustive list, these algorithms are common enough that every machine learning practitioner should know about them. They also have convenient `R` packages that allow for easy coding.
#
# In this tutorial, we'll focus heavily on how to **interpret** the output of machine learning models -- or, at least, how not to _mis_-interpret it. However, in this chapter we won’t be making any causal claims about the relationships between variables yet. But please hang tight, as estimating causal effects will be one of the main topics presented in the next chapters.
#
# For the remainder of the chapter we will use a real dataset. Each row in this data set represents the characteristics of a owner-occupied housing unit. Our goal is to predict the (log) price of the housing unit (`LOGVALUE`, our outcome variable) from features such as the size of the lot (`LOT`) and square feet area (`UNITSF`), number of bedrooms (`BEDRMS`) and bathrooms (`BATHS`), year in which it was built (`BUILT`) etc. This dataset comes from the American Housing Survey and was used in [Mullainathan and Spiess (2017, JEP)](https://www.aeaweb.org/articles?id=10.1257/jep.31.2.87). In addition, we will append to this data columns that are pure noise. Ideally, our fitted model should not take them into acccount.

# %%
import requests
import io

url = 'https://docs.google.com/uc?id=1qHr-6nN7pCbU8JUtbRDtMzUKqS9ZlZcR&export=download'
urlData = requests.get(url).content
data = pd.read_csv(io.StringIO(urlData.decode('utf-8')))
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# outcome variable name
outcome = 'LOGVALUE'

# covariates
true_covariates = ['LOT','UNITSF','BUILT','BATHS','BEDRMS','DINING','METRO','CRACKS','REGION','METRO3','PHONE','KITCHEN','MOBILTYP','WINTEROVEN','WINTERKESP','WINTERELSP','WINTERWOOD','WINTERNONE','NEWC','DISH','WASH','DRY','NUNIT2','BURNER','COOK','OVEN','REFR','DENS','FAMRM','HALFB','KITCH','LIVING','OTHFN','RECRM','CLIMB','ELEV','DIRAC','PORCH','AIRSYS','WELL','WELDUS','STEAM','OARSYS']
p_true = len(true_covariates)

# noise covariates added for didactic reasons

p_noise = 20

noise_covariates = []
for x in range(1, p_noise+1):
    noise_covariates.append('noise{0}'.format(x))

covariates = true_covariates + noise_covariates

x_noise = np.random.rand(data.shape[0] * p_noise).reshape(28727,20)
x_noise = pd.DataFrame(x_noise, columns=noise_covariates)
data = pd.concat([data, x_noise], axis=1)

# sample size
n = data.shape[0]

# total number of covariates
p = len(covariates)
p
# Out:
# 63

# %% [markdown]
# Here's the correlation between the first few covariates. Note how, most variables are positively correlated, which is expected since houses with more bedrooms will usually also have more bathrooms, larger area, etc.

# %%
data.head()
# Out:
#     LOGVALUE  REGION  METRO  METRO3  PHONE  KITCHEN  MOBILTYP  WINTEROVEN  \
# 0  13.487006       4      7       2      1        1        -1           2
# 1  13.217674       4      7       2      1        1        -1           2
# 2  13.487006       4      7       2      1        1        -1           2
# 3  13.017003       4      7       2      1        1        -1           2
# 4  13.458836       4      7       2      1        1        -1           2
#
#    WINTERKESP  WINTERELSP  ...   noise11   noise12   noise13   noise14  \
# 0           2           1  ...  0.517363  0.222421  0.474230  0.728142
# 1           2           2  ...  0.420457  0.777245  0.171630  0.519609
# 2           2           2  ...  0.004543  0.968520  0.271582  0.135750
# 3           2           2  ...  0.783787  0.925208  0.758699  0.683430
# 4           2           2  ...  0.133966  0.010568  0.312687  0.635638
#
#     noise15   noise16   noise17   noise18   noise19   noise20
# 0  0.727689  0.472786  0.737210  0.787950  0.846028  0.553807
# 1  0.874213  0.575951  0.692399  0.586295  0.523363  0.608005
# 2  0.135611  0.013497  0.499389  0.101627  0.902367  0.172846
# 3  0.522622  0.537227  0.177706  0.353235  0.307487  0.708843
# 4  0.577889  0.348718  0.470229  0.426971  0.509135  0.088554
#
# [5 rows x 186 columns]

# %%
data.loc[:,covariates[0:8]].corr()
# Out:
#              LOT    UNITSF     BUILT     BATHS    BEDRMS    DINING     METRO  \
# LOT     1.000000  0.064841  0.044639  0.057325  0.009626 -0.015348  0.136258
# UNITSF  0.064841  1.000000  0.143201  0.428723  0.361165  0.214030  0.057441
# BUILT   0.044639  0.143201  1.000000  0.434519  0.215109  0.037468  0.323703
# BATHS   0.057325  0.428723  0.434519  1.000000  0.540230  0.259457  0.189812
# BEDRMS  0.009626  0.361165  0.215109  0.540230  1.000000  0.281846  0.121331
# DINING -0.015348  0.214030  0.037468  0.259457  0.281846  1.000000  0.022026
# METRO   0.136258  0.057441  0.323703  0.189812  0.121331  0.022026  1.000000
# CRACKS  0.016851  0.033548  0.092390  0.062819  0.026779  0.021270  0.057545
#
#           CRACKS
# LOT     0.016851
# UNITSF  0.033548
# BUILT   0.092390
# BATHS   0.062819
# BEDRMS  0.026779
# DINING  0.021270
# METRO   0.057545
# CRACKS  1.000000

# %% [markdown]
# ### 2.2.1 Generalized linear models

# %% [markdown]
# This class of models extends common methods such as linear and logistic regression by adding a penalty to the magnitude of the coefficients. **Lasso** penalizes the absolute value of slope coefficients. For regression problems, it becomes
# \begin{equation}
#
#   \hat{b}_{Lasso} = \arg\min_b \sum_{i=1}^m
#     \left( Y_i - b_0 - X_{i1}b_1 - \cdots - X_{ip}b_p \right)^2
#     - \lambda \sum_{j=1}^p |b_j|
# \end{equation}
#
#
# Similarly, in a regression problem **Ridge** penalizes the sum of squares of the slope coefficients,
# \begin{equation}
#
#   \hat{b}_{Ridge} = \arg\min_b \sum_{i=1}^m
#     \left( Y_i - b_0 - X_{i1}b_1 - \cdots - X_{ip}b_p \right)^2
#     - \lambda \sum_{j=1}^p b_j^2
# \end{equation}
#
# Also, there exists the **Elastic Net** penalization which consists of a convex combination between the other two. In all cases, the scalar parameter
# $\lambda$ controls the complexity of the model. For $\lambda=0$, the problem reduces to the “usual” linear regression. As $\lambda$ increases, we favor simpler models. As we’ll see below, the optimal parameter $\lambda$ is selected via cross-validation.
#
# An important feature of Lasso-type penalization is that it promotes **sparsity** – that is, it forces many coefficients to be exactly zero. This is different from Ridge-type penalization, which forces coefficients to be small.
#
# Another interesting property of these models is that, even though they are called “linear” models, this should actually be understood as **linear in transformations** of the covariates. For example, we could use polynomials or splines (continuous piecewise polynomials) of the covariates and allow for much more flexible models.
#
# In fact, because of the penalization term, problems \@ref(eq:lasso) and \@ref(eq:ridge) remain well-defined and have a unique solution even in **high-dimensional** problems in which the number of coefficients $p$ is larger than the sample size $n$ – that is, our data is “fat” with more columns than rows. These situations can arise either naturally (e.g. genomics problems in which we have hundreds of thousands of gene expression information for a few individuals) or because we are including many transformations of a smaller set of covariates.
#
# Finally, although here we are focusing on regression problems, other generalized linear models such as logistic regression can also be similarly modified by adding a Lasso, Ridge, or Elastic Net-type penalty to similar consequences.
#
# In our example we will use the `glmnet` package; see this [vignette](https://web.stanford.edu/~hastie/glmnet/glmnet_alpha.html) for more information about the package, including how to use glmnet for other types of outcomes (binomial, categorical, multi-valued). The function `cv.glmnet` automatically performs k-fold cross-validation.
#
# Also, to emphasize the point about linearity in transformations of the covariates, we will use splines of our independent variables (i.e., we will use piecewise continuous polynomials of the original covariates). This is done using the function `bs`; see this [primer](https://cran.r-project.org/web/packages/crs/vignettes/spline_primer.pdf) for more information.

# %%
alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)

X = data.loc[:,covariates]
Y = data.loc[:,outcome]

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge

# %%
scaler = StandardScaler()
X_transformed = scaler.fit_transform(X)

# %%
lassocv = LassoCV(n_alphas=200, cv=10)

# %%
lassocv.fit(X,Y)
# Out:
# LassoCV(cv=10, n_alphas=200)

# %%
lassocv.score(X,Y)
# Out:
# 0.08003695446424386

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)
scores = np.empty_like(alphas)
for i,a in enumerate(alphas):
    lasso = Lasso()
    lasso.set_params(alpha=a)
    scorer = make_scorer(mean_squared_error)
    scores[i] = cross_val_score(lasso, X, Y, scoring=scorer, cv=10).mean()
    
    
lassocv = LassoCV()
lassocv.fit(X, Y)
lassocv_score = lassocv.score(X, Y)
lassocv_alpha = lassocv.alpha_
print('CV', lassocv.coef_)

plt.plot(alphas, scores, '-ko')
#plt.axhline(lassocv_score, color='b', ls='--')
#plt.axvline(lassocv_alpha, color='b', ls='--')
plt.xlabel(r'$\alpha$')
plt.ylabel('Score')
plt.xscale('log')
#sns.despine(offset=15)
# Out:
# CV [ 2.05211715e-07  1.19729262e-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00]

# %%
import sklearn.datasets
#from sklearn.model_selection import cross_validate as cv
from sklearn import linear_model


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)
scores = np.empty_like(alphas)
for i,a in enumerate(alphas):
    lasso = linear_model.Lasso()
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    scores[i] = lasso.score(X_test, y_test)
    print(a, lasso.coef_)
    
lassocv = linear_model.LassoCV()
lassocv.fit(X, Y)
lassocv_score = lassocv.score(X, Y)
lassocv_alpha = lassocv.alpha_
print('CV', lassocv.coef_)

plt.plot(alphas, scores, '-ko')
#plt.axhline(lassocv_score, color='b', ls='--')
#plt.axvline(lassocv_alpha, color='b', ls='--')
plt.xlabel(r'$\alpha$')
append(cross_val_score(lasso, X, Y, scoring=scorer, cv=10).max())
    mse_mean.append(cross_val_score(lasso, X, Y, scoring=scorer, cv=10).mean())

# %%
lasso_alphas = np.linspace(0, 2, 1000)
lasso= Lasso()
grid = dict()
grid['alpha'] = lasso_alphas
scorer = make_scorer(mean_squared_error)

gscv = GridSearchCV(
    lasso, grid, scoring=scorer,
    cv=10 
)
results = gscv.fit(X, Y)

# %%
lasso = Lasso()
alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)



tuned_parameters = [{"alpha": alphas}]
n_folds = 10

scorer = make_scorer(mean_squared_error)

clf = GridSearchCV(lasso, tuned_parameters, cv=n_folds, refit=False, scoring=scorer)
clf.fit(X, Y)
scores = clf.cv_results_["mean_test_score"]
scores_std = clf.cv_results_["std_test_score"]

# %% [markdown]
# The next figure plots the average estimated MSE for each lambda. The red dots are the averages across all folds, and the error bars are based on the variability of mse estimates across folds. The vertical dashed lines show the (log) lambda with smallest estimated MSE (left) and the one whose mse is at most one standard error from the first (right).

# %%
plt.figure().set_size_inches(8, 6)
plt.semilogx(alphas, scores)


# plot error lines showing +/- std. errors of the scores
std_error = scores_std / np.sqrt(n_folds)

plt.semilogx(alphas, scores + std_error, "b--")
plt.semilogx(alphas, scores - std_error, "b--")

# alpha=0.2 controls the translucency of the fill color
plt.fill_between(alphas, scores + std_error, scores - std_error, alpha=0.2)

plt.ylabel("CV score +/- std error")
plt.xlabel("alpha")
plt.axhline(np.max(scores), linestyle="--", color=".5")
plt.xlim([alphas[0], alphas[-1]])
# Out:
# (1e-08, 0.1)

# %% [markdown]
# Here are the first few estimated coefficients at the $\lambda$ value that minimizes cross-validated MSE. Note that many estimated coefficients them are exactly zero.

# %%
clf.best_params_
# Out:
# {'alpha': 0.1}

# %%
lasso = Lasso(alpha=clf.best_params_['alpha'])
lasso.fit(X,Y)
table = np.zeros((1,5))
table[0,0] = lasso.intercept_
table[0,1] = lasso.coef_[0]
table[0,2] = lasso.coef_[1]
table[0,3] = lasso.coef_[2]
table[0,4] = lasso.coef_[3]
pd.DataFrame(table, columns=['(Intercept)','LOT','UNITSF','BUILT','BATHS'], index=['Coef.'])
# Out:
#        (Intercept)           LOT    UNITSF     BUILT     BATHS
# Coef.     2.680718  2.532409e-07  0.000085  0.004487  0.138486

# %%
print("Number of nonzero coefficients at optimal lambda:", len(lasso.coef_[lasso.coef_ != 0]), "out of " , len(lasso.coef_))
# Out:
# Number of nonzero coefficients at optimal lambda: 7 out of  63

# %% [markdown]
# Predictions and estimated MSE for the selected model are retrieved as follows.

# %%
from sklearn.linear_model import lasso_path
eps = 5e-3 
alphas_lasso, coefs_lasso, _ = lasso_path(X, Y, eps=eps)

# %%
len(coefs_lasso)
# Out:
# 63

# %% [markdown]
# The next command plots estimated coefficients as a function of the regularization parameter $\lambda$.

# %%
coefs = []
for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X, Y)
    coefs.append(lasso.coef_)

# %%
from matplotlib.pyplot import figure

plt.figure(figsize=(18,6))
plt.gca().plot(alphas, coefs)
plt.gca().set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha');

# %% [markdown]
# It's tempting to try to interpret the coefficients obtained via Lasso. Unfortunately, that can be very difficult, because by dropping covariates Lasso introduces a form of **omitted variable bias** ([wikipedia](https://en.wikipedia.org/wiki/Omitted-variable_bias)). To understand this form of bias, consider the following toy example. We have two positively correlated independent variables, `x.1` and `x.2`, that are linearly related to the outcome `y`. Linear regression of `y` on `x1` and `x2` gives us the correct coefficients. However, if we _omit_ `x2` from the estimation model, the coefficient on `x1` increases. This is because `x1` is now "picking up" the effect of the variable that was left out. In other words, the effect of `x1` seems stronger because we aren't controlling for some other confounding variable. Note that the second model this still works for prediction, but we cannot interpret the coefficient as a measure of strength of the causal relationship between `x1` and `y`.

# %%
mean = [0.0,0.0]
cov = [[1.5,0.5],[0.5,1.5]]

x1, x2 = np.random.multivariate_normal(mean, cov, 100000).T
y = 1 + 2*x1 + 3*x2 + np.random.rand(100000)
data_sim = pd.DataFrame(np.array([x1,x2,y]).T,columns=['x1','x2','y'] )

print('Correct Model')
# Out:
# Correct Model

# %%
import statsmodels.formula.api as smf

result = smf.ols('y ~ x1 + x2', data = data_sim).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 1.522e+07
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):               0.00
# Time:                        19:01:05   Log-Likelihood:                -17637.
# No. Observations:              100000   AIC:                         3.528e+04
# Df Residuals:                   99997   BIC:                         3.531e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.5005      0.001   1643.890      0.000       1.499       1.502
# x1             1.9999      0.001   2527.984      0.000       1.998       2.001
# x2             3.0010      0.001   3796.496      0.000       2.999       3.003
# ==============================================================================
# Omnibus:                    86535.897   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5974.109
# Skew:                          -0.004   Prob(JB):                         0.00
# Kurtosis:                       1.803   Cond. No.                         1.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print("Model with omitted variable bias")

result = smf.ols('y ~ x1', data = data_sim).fit()
print(result.summary())
# Out:
# Model with omitted variable bias
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.525
# Method:                 Least Squares   F-statistic:                 1.104e+05
# Date:                Sun, 05 Jun 2022   Prob (F-statistic):               0.00
# Time:                        19:01:05   Log-Likelihood:            -2.6652e+05
# No. Observations:              100000   AIC:                         5.330e+05
# Df Residuals:                   99998   BIC:                         5.331e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4978      0.011    136.202      0.000       1.476       1.519
# x1             2.9893      0.009    332.198      0.000       2.972       3.007
# ==============================================================================
# Omnibus:                        0.434   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.805   Jarque-Bera (JB):                0.441
# Skew:                          -0.004   Prob(JB):                        0.802
# Kurtosis:                       2.994   Cond. No.                         1.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The phenomenon above occurs in Lasso and in any other sparsity-promoting method when correlated covariates are present since, by forcing coefficients to be zero, Lasso is effectively dropping them from the model. And as we have seen, as a variable gets dropped, a different variable that is correlated with it can "pick up" its effect, which in turn can cause bias. Once $\lambda$ grows sufficiently large, the penalization term overwhelms any benefit of having that variable in the model, so that variable finally decreases to zero too.
#
# One may instead consider using Lasso to select a subset of variables, and then regressing the outcome on the subset of selected variables via OLS (without any penalization). This method is often called **post-lasso**. Although it has desirable properties in terms of model fit (see e.g., [Belloni and Chernozhukov, 2013](https://arxiv.org/pdf/1001.0188.pdf)), this procedure does not solve the omitted variable issue we mentioned above.
#
# We illustrate this next. We observe the path of the estimated coefficient on the number of bathroooms (`BATHS`) as we increase $\lambda$.

# %%
scale_X = StandardScaler().fit(X).transform(X)
ols = LinearRegression()
ols.fit(scale_X,Y)
ols_coef = ols.coef_[3]
lamdas = np.linspace(0.01,0.4, 200)


coef_ols = np.repeat(ols_coef,200)
###############################################

lasso_bath_coef = []
lasso_coefs=[]
for a in lamdas:
    lasso.set_params(alpha=a,normalize = False)
    lasso.fit(scale_X, Y)
    lasso_bath_coef.append(lasso.coef_[3])
    lasso_coefs.append(lasso.coef_)
#################################################   

ridge_bath_coef = []
for a in lamdas:
    ridge = Ridge(alpha=a,normalize = True)
    ridge.fit(scale_X, Y)
    ridge_bath_coef.append(ridge.coef_[3])
####################################################

poslasso_coef = [ ]
for a in range(200):
    scale_X = StandardScaler().fit(X.iloc[:, (lasso_coefs[a] !=  0)]).transform(X.iloc[:, (lasso_coefs[a] !=  0)])
    ols = LinearRegression()
    ols.fit(scale_X,Y)  
    post_coef = ols.coef_[X.iloc[:, (lasso_coefs[a] !=  0)].columns.get_loc('BATHS')]                             
    poslasso_coef.append(post_coef )    
    
    
#################################################
plt.figure(figsize=(18,5))
plt.plot(lamdas, ridge_bath_coef, label = 'Ridge', color = 'g', marker='+', linestyle = ':',markevery=8)
plt.plot(lamdas, lasso_bath_coef, label = 'Lasso', color = 'r', marker = '^',linestyle = 'dashed',markevery=8)
plt.plot(lamdas, coef_ols, label = 'OLS', color = 'b',marker = 'x',linestyle = 'dashed',markevery=8)
plt.plot(lamdas, poslasso_coef, label = 'postlasso',color='black',marker = 'o',linestyle = 'dashed',markevery=8 )
plt.legend()
plt.title("Coefficient estimate on Baths")
plt.ylabel('Coef')
plt.xlabel('lambda')
# Out:
# Text(0.5, 0, 'lambda')

# %% [markdown]
# The OLS coefficients are not penalized, so they remain constant. Ridge estimates decrease monotonically as $\lambda$ grows. Also, for this dataset, Lasso estimates first increase and then decrease. Meanwhile, the post-lasso coefficient estimates seem to behave somewhat erratically with $lambda$. To understand this behavior, let's see what happens to the magnitude of other selected variables that are correlated with `BATHS`.

# %%
scale_X = StandardScaler().fit(X).transform(X)
UNITSF_coef = []
BEDRMS_coef = []
DINING_coef = []
for a in lamdas:
    lasso.set_params(alpha=a,normalize = False)
    lasso.fit(scale_X, Y)
    UNITSF_coef.append(lasso.coef_[1])
    BEDRMS_coef.append(lasso.coef_[4])
    DINING_coef.append(lasso.coef_[5])

# %%
plt.figure(figsize=(18,5))
plt.plot(lamdas, UNITSF_coef,label = 'UNITSF', color = 'black' )
plt.plot(lamdas, BEDRMS_coef,label = 'BEDRMS', color = 'red',  linestyle = '--')
plt.plot(lamdas, DINING_coef,label = 'DINING', color = 'g',linestyle = 'dotted')
plt.legend()
plt.ylabel('Coef')
plt.xlabel('lambda')
# Out:
# Text(0.5, 0, 'lambda')

# %% [markdown]
# Note how the discrete jumps in magnitude for the `BATHS` coefficient in the first coincide with, for example, variables `DINING` and `BEDRMS` being exactly zero. As these variables got dropped from the model, the coefficient on `BATHS` increased to pick up their effect.
#
# Another problem with Lasso coefficients is their instability. When multiple variables are highly correlated we may spuriously drop several of them. To get a sense of the amount of variability, in the next snippet we fix $\lambda$ and then look at the lasso coefficients estimated during cross-validation. We see that by simply removing one fold we can get a very different set of coefficients (nonzero coefficients are in black in the heatmap below). This is because there may be many choices of coefficients with similar predictive power, so the set of nonzero coefficients we end up with can be quite unstable.

# %%
import itertools
nobs = X.shape[0]

nfold = 10
    # Define folds indices 
list_1 = [*range(0, nfold, 1)]*nobs
sample = np.random.choice(nobs,nobs, replace=False).tolist()
foldid = [list_1[index] for index in sample]

    # Create split function(similar to R)
def split(x, f):
    count = max(f) + 1
    return tuple( list(itertools.compress(x, (el == i for el in f))) for i in range(count) ) 

    # Split observation indices into folds 
list_2 = [*range(0, nobs, 1)]
I = split(list_2, foldid)

# %%
lasso_coef_fold=[]
for b in range(0,len(I)):
    
        # Split data - index to keep are in mask as booleans
        include_idx = set(I[b])  #Here should go I[b] Set is more efficient, but doesn't reorder your elements if that is desireable
        mask = np.array([(i in include_idx) for i in range(len(X))])

        # Lasso regression, excluding folds selected 
        
        lassocv = LassoCV(random_state=0)
        lassocv.fit(scale_X[~mask], Y[~mask])
        lasso_coef_fold.append(lassocv.coef_)

# %%
index_val = ['Fold-1','Fold-2','Fold-3','Fold-4','Fold-5','Fold-6','Fold-7','Fold-8','Fold-9','Fold-10']
df = pd.DataFrame(data= lasso_coef_fold, columns=X.columns, index = index_val).T
df.style.applymap(lambda x: "background-color: black" if x==0 else "background-color: white")
# Out:
# <style type="text/css">
# #T_8001a_row0_col0, #T_8001a_row0_col1, #T_8001a_row0_col2, #T_8001a_row0_col3, #T_8001a_row0_col4, #T_8001a_row0_col5, #T_8001a_row0_col6, #T_8001a_row0_col7, #T_8001a_row0_col8, #T_8001a_row0_col9, #T_8001a_row1_col0, #T_8001a_row1_col1, #T_8001a_row1_col2, #T_8001a_row1_col3, #T_8001a_row1_col4, #T_8001a_row1_col5, #T_8001a_row1_col6, #T_8001a_row1_col7, #T_8001a_row1_col8, #T_8001a_row1_col9, #T_8001a_row2_col1, #T_8001a_row2_col2, #T_8001a_row2_col3, #T_8001a_row2_col4, #T_8001a_row2_col5, #T_8001a_row2_col6, #T_8001a_row2_col7, #T_8001a_row2_col8, #T_8001a_row2_col9, #T_8001a_row3_col0, #T_8001a_row3_col1, #T_8001a_row3_col2, #T_8001a_row3_col3, #T_8001a_row3_col4, #T_8001a_row3_col5, #T_8001a_row3_col6, #T_8001a_row3_col7, #T_8001a_row3_col8, #T_8001a_row3_col9, #T_8001a_row4_col0, #T_8001a_row4_col1, #T_8001a_row4_col2, #T_8001a_row4_col3, #T_8001a_row4_col4, #T_8001a_row4_col5, #T_8001a_row4_col6, #T_8001a_row4_col7, #T_8001a_row4_col8, #T_8001a_row4_col9, #T_8001a_row5_col0, #T_8001a_row5_col1, #T_8001a_row5_col2, #T_8001a_row5_col3, #T_8001a_row5_col4, #T_8001a_row5_col5, #T_8001a_row5_col6, #T_8001a_row5_col7, #T_
8001a_row21_col8, #T_8001a_row21_col9, #T_8001a_row22_col0, #T_8001a_row22_col1, #T_8001a_row22_col2, #T_8001a_row22_col3, #T_8001a_row22_col4, #T_8001a_row22_col5, #T_8001a_row22_col6, #T_8001a_row22_col7, #T_8001a_row22_col8, #T_8001a_row22_col9, #T_8001a_row23_col4, #T_8001a_row26_col5, #T_8001a_row27_col0, #T_8001a_row27_col1, #T_8001a_row27_col2, #T_8001a_row27_col3, #T_8001a_row27_col4,  ...

# %% [markdown]
# As we have seen above, any interpretation needs to take into account the joint distribution of covariates. One possible heuristic is to consider **data-driven subgroups**. For example, we can analyze what differentiates observations whose predictions are high from those whose predictions are low. The following code estimates a flexible Lasso model with splines, ranks the observations into a few subgroups according to their predicted outcomes, and then estimates the average covariate value for each subgroup.

# %%
lassocv = LassoCV(random_state=0)
lassocv.fit(scale_X, Y)
lassocv.predict(scale_X)
# Out:
# array([12.31666465, 11.65347361, 12.50484166, ..., 12.06438534,
#        11.85200243, 12.05478082])

# %%
import itertools
nobs = X.shape[0]

nfold = 5
    # Define folds indices 
list_1 = [*range(0, nfold, 1)]*nobs
sample = np.random.choice(nobs,nobs, replace=False).tolist()
foldid = [list_1[index] for index in sample]

    # Create split function(similar to R)
def split(x, f):
    count = max(f) + 1
    return tuple( list(itertools.compress(x, (el == i for el in f))) for i in range(count) ) 

    # Split observation indices into folds 
list_2 = [*range(0, nobs, 1)]
I = split(list_2, foldid)

lasso_coef_rank=[]
lasso_pred = []
for b in range(0,len(I)):
        # Split data - index to keep are in mask as booleans
        include_idx = set(I[b])  #Here should go I[b] Set is more efficient, but doesn't reorder your elements if that is desireable
        mask = np.array([(i in include_idx) for i in range(len(X))])

        # Lasso regression, excluding folds selected 
        
        lassocv = LassoCV(random_state=0)
        lassocv.fit(scale_X[~mask], Y[~mask])
        lasso_coef_rank.append(lassocv.coef_)
        lasso_pred.append(lassocv.predict(scale_X[mask]))

# %%
def funcion():
    y_hat_cros.val = lasso_pred[i]

# %%
range(1,5)
# Out:
# range(1, 5)

# %%
ga = pd.DataFrame(y_hat[2])

# %%
b =pd.cut(ga[0], bins =[np.percentile(ga,0),np.percentile(ga,25),np.percentile(ga,50),
           np.percentile(ga,75),np.percentile(ga,100)], labels = [1,2,3,4])

# %%
uwu = pd.DataFrame()
for i in [0,1,2,3,4]:
    ga = pd.DataFrame(y_hat[i])
    
    b =pd.cut(ga[0], bins =[np.percentile(ga,0),np.percentile(ga,25),np.percentile(ga,50),
           np.percentile(ga,75),np.percentile(ga,100)], labels = [1,2,3,4])
    
    uwu = pd.concat([uwu, b])

# %%
uwu =uwu.apply(lambda x: pd.factorize(x)[0])

# %%
uwu.rename(columns={0:'ranking'}, inplace=True)

# %%
import statsmodels.api as sm

import statsmodels.formula.api as smf

# %%
uwu.value_counts()
# Out:
# ranking
#  0         7182
#  1         7180
#  2         7180
#  3         7180
# -1            5
# dtype: int64

# %%
y = X[covariates[1]]
x = uwu

# %%
uwu =uwu.reset_index().drop(columns=['index'])

# %%
print(sm.OLS(y, x).fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 UNITSF   R-squared (uncentered):                   0.364
# Model:                            OLS   Adj. R-squared (uncentered):              0.364
# Method:                 Least Squares   F-statistic:                          1.643e+04
# Date:                Mon, 06 Jun 2022   Prob (F-statistic):                        0.00
# Time:                        00:36:57   Log-Likelihood:                     -2.6620e+05
# No. Observations:               28727   AIC:                                  5.324e+05
# Df Residuals:                   28726   BIC:                                  5.324e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ranking     1034.7710      8.073    128.176      0.000    1018.947    1050.595
# ==============================================================================
# Omnibus:                    19906.889   Durbin-Watson:                   1.487
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           363720.080
# Skew:                           3.141   Prob(JB):                         0.00
# Kurtosis:                      19.260   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The next heatmap visualizes the results. Note how observations ranked higher (i.e., were predicted to have higher prices) have more bedrooms and baths, were built more recently, have fewer cracks, and so on. The next snippet of code displays the average covariate per group along with each standard errors. The rows are ordered according to $Var(E[X_{ij} | G_i) / Var(X_i)$, where $G_i$ denotes the ranking. This is a rough normalized measure of how much variation is "explained" by group membership $G_i$. Brighter colors indicate larger values.

# %% [markdown]
# As we just saw above, houses that have, e.g., been built more recently (`BUILT`), have more baths (`BATHS`) are associated with larger price predictions.
#
# This sort of interpretation exercise did not rely on reading any coefficients, and in fact it could also be done using any other flexible method, including decisions trees and forests.

# %% [markdown]
# ### 2.2.2 Decision Tree

# %% [markdown]
# This next class of algorithms divides the covariate space into "regions" and estimates a constant prediction within each region.
#
# To estimate a decision tree, we following a recursive partition algorithm. At each stage, we select one variable $j$ and one split point
# $s$, and divide the observations into “left” and “right” subsets, depending on whether $X_{ij} \leq s$ or $X_{ij} > s$. For regression problems, the variable and split points are often selected so that the sum of the variances of the outcome variable in each “child” subset is smallest. For classification problems, we split to separate the classes. Then, for each child, we separately repeat the process of finding variables and split points. This continues until a minimum subset size is reached, or improvement falls below some threshold.
#
# At prediction time, to find the predictions for some point $x$, we just follow the tree we just built, going left or right according to the selected variables and split points, until we reach a terminal node. Then, for regression problems, the predicted value at some point $x$ is the average outcome of the observations in the same partition as the point $x$. For classification problems, we output the majority class in the node.
#
# Let’s estimate a decision tree using the `R` package rpart; see [this tutorial](https://cran.r-project.org/web/packages/rpart/vignettes/longintro.pdf) for more information about it.

# %%
from sklearn.tree import DecisionTreeRegressor
import graphviz
from sklearn import tree
from sklearn.tree import export_graphviz 
from sklearn.metrics import accuracy_score

dt = DecisionTreeRegressor(ccp_alpha=0, max_depth= 15)
x_train, x_test, y_train, y_test = train_test_split(scale_X, Y, test_size=.3)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0, max_depth=15)

# %%
y_predict = dt.predict(x_test)
mean_squared_error(y_test, y_predict)
# Out:
# 0.9774334015211881

# %% [markdown]
# At this point, we have not constrained the complexity of the tree in any way, so it's likely too deep and probably overfits. Here’s a plot of what we have so far (without bothering to label the splits to avoid clutter).

# %%
plt.figure(figsize=(18,5))
tree.plot_tree(dt)
# Out:
# [Text(0.6821968647427427, 0.96875, 'X[22] <= 3.425\nsquared_error = 0.97\nsamples = 20108\nvalue = 11.815'),
#  Text(0.4308084716952982, 0.90625, 'X[1] <= 0.003\nsquared_error = 0.786\nsamples = 19390\nvalue = 11.886'),
#  Text(0.19281828802378617, 0.84375, 'X[3] <= -0.559\nsquared_error = 0.674\nsamples = 13890\nvalue = 11.678'),
#  Text(0.08294990728505051, 0.78125, 'X[30] <= -4.316\nsquared_error = 0.798\nsamples = 5106\nvalue = 11.379'),
#  Text(0.08260888678119271, 0.71875, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.08329092778890831, 0.71875, 'X[29] <= 0.044\nsquared_error = 0.773\nsamples = 5105\nvalue = 11.381'),
#  Text(0.057332740099748494, 0.65625, 'X[42] <= -1.273\nsquared_error = 0.883\nsamples = 2912\nvalue = 11.249'),
#  Text(0.03364913252909331, 0.59375, 'X[8] <= 1.162\nsquared_error = 0.97\nsamples = 1054\nvalue = 11.077'),
#  Text(0.016443582420393028, 0.53125, 'X[6] <= -1.58\nsquared_error = 0.854\nsamples = 962\nvalue = 11.015'),
#  Text(0.006713841169700328, 0.46875, 'X[48] <= -1.654\nsquared_error = 0.858\nsamples = 504\nvalue = 10.839'),
#  Text(0.0006820410077155889, 0.40625, 'X[54] <= -1.569\nsquared_error = 8.674\nsamples = 16\nvalue = 9.462'),
#  Text(0.00034102050385779445, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.0010230615115733833, 0.34375, 'X[57] <= -1.694\nsquared_error = 2.886\nsamples = 15\nvalue = 10.093'),
#  Text(0.0006820410077155889, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 4.248'),
#  Text(0.0013640820154311778, 0.28125, 'X[55] <= -0.818\nsquared_error = 0.478\nsamples = 14\nvalue = 10.51'),
#  Text(0.0010230615115733833, 0.21875, 'squared_error = 0.0\nsamples = 2\nvalue = 9.21'),
#  Text(0.0017051025192889723, 0.21875, 'X[48] <= -1.666\nsquared_error = 0.229\nsamples = 12\nvalue = 10.727'),
#  Text(0.0006820410077155889, 0.15625, 'X[57] <= -1.543\nsquared_error = 0.105\nsamples = 9\nvalue = 10.923'),
#  Text(0.00034102050385779445, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.678'),
#  Text(0.0010230615115733833, 0.09375, 'X[4] <= -0.879\nsquared_error = 0.038\nsamples = 8\nvalue = 10.829'),
#  Text(0.0006820410077155889, 0.03125, 'squared_error = 0.004\nsamples = 2\nvalue = 10.53'),
#  Text(0.0013640820154311778, 0.03125, 'squared_error = 0.009\nsamples = 6\nvalue = 10.929'),
#  Text(0.0027281640308623556, 0.15625, 'X[0] <= -0.329\nsquared_error = 0.137\nsamples = 3\nvalue = 10.138'),
#  Text(0.002387143527004561, 0.09375, 'X[60] <= -0.113\nsquared_error = 0.001\nsamples = 2\nvalue = 10.399'),
#  Text(0.0020461230231467666, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.364'),
#  Text(0.0027281640308623556, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 10.434'),
#  Text(0.00306918453472015, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.012745641331685067, 0.40625, 'X[8] <= -1.762\nsquared_error = 0.538\nsamples = 488\nvalue = 10.884'),
#  Text(0.008866533100302656, 0.34375, 'X[46] <= 1.546\nsquared_error = 0.499\nsamples = 68\nvalue = 10.479'),
#  Text(0.006820410077155889, 0.28125, 'X[46] <= -1.338\nsquared_error = 0.418\nsamples = 65\nvalue = 10.539'),
#  Text(0.005115307557866917, 0.21875, 'X[57] <= 0.068\nsquared_error = 0.357\nsamples = 11\nvalue = 9.976'),
#  Text(0.004092246046293533, 0.15625, 'X[45] <= -0.318\nsquared_error = 0.09\nsamples = 5\nvalue = 9.44'),
#  Text(0.003751225542435739, 0.09375, 'squared_error = 0.0\nsamples = 3\nvalue = 9.21'),
#  Text(0.004433266550151328, 0.09375, 'X[35] <= 2.677\nsquared_error = 0.028\nsamples = 2\nvalue = 9.784'),
#  Text(0.004092246046293533, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 9.952'),
#  Text(0.004774287054009122, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.0061383690694403, 0.15625, 'X[55] <= 0.701\nsquared_error = 0.14\nsamples = 6\nvalue = 10.422'),
#  Text(0.005797348565582505, 0.09375, 'X[46] <= -1.546\nsquared_error = 0.009\nsamples = 4\nvalue = 10.682'),
#  Text(0.005456328061724711, 0.03125, 'squared_error = 0.003\nsamples = 2\nvalue = 10.767'),
#  Text(0.0061383690694403, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 10.597'),
#  Text(0.006479389573298094, 0.09375, 'squared_error = 0.0\nsamples = 2\nvalue = 9.903'),
#  Text(0.008525512596444861, 0.21875, 'X[57] <= 0.453\nsquared_error = 0.352\nsamples = 54\nvalue = 10.654'),
#  Text(0.007502451084871478, 0.15625, 'X[47] <= -1.659\nsquared_error = 0.201\nsamples = 36\nvalue = 10.85'),
#  Text(0.007161430581013683, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.007843471588729273, 0.09375, 'X[2] <= -2.135\nsquared_error = 0.163\nsamples = 35\nvalue = 10.885'),
#  Text(0.007502451084871478, 0.03125, 'squared_error = 0.219\nsamples = 16\nvalue = 10.692'),
#  Text(0.008184492092587066, 0.03125, 'squared_error = 0.057\nsamples = 19\nvalue = 11.047'),
#  Text(0.009548574108018244, 0.15625, 'X[53] <= 1.565\nsquared_error = 0.424\nsamples = 18\nvalue = 10.262'),
#  Text(0.00920755360416045, 0.09375, 'X[54] <= 1.491\nsquared_error = 0.287\nsamples = 17\nvalue = 10.167'),
#  Text(0.008866533100302656, 0.03125, 'squared_error = 0.187\nsamples = 15\nvalue = 10.295'),
#  Text(0.009548574108018244, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 9.21'),
#  Text(0.00988959461187604, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 11.871'),
#  Text(0.010912656123449422, 0.28125, 'X[51] <= 1.036\nsquared_error = 0.51\nsamples = 3\nvalue = 9.183'),
#  Text(0.010571635619591627, 0.21875, 'X[46] <= 1.593\nsquared_error = 0.173\nsamples = 2\nvalue = 9.627'),
#  Text(0.010230615115733834, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 9.21'),
#  Text(0.010912656123449422, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 10.043'),
#  Text(0.011253676627307217, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 8.294'),
#  Text(0.01662474956306748, 0.34375, 'X[52] <= 1.699\nsquared_error = 0.513\nsamples = 420\nvalue = 10.95'),
#  Text(0.01415235091009847, 0.28125, 'X[57] <= 1.482\nsquared_error = 0.476\nsamples = 412\nvalue = 10.97'),
#  Text(0.012447248390809497, 0.21875, 'X[53] <= 1.709\nsquared_error = 0.467\nsamples = 390\nvalue = 10.996'),
#  Text(0.01159469713116501, 0.15625, 'X[51] <= 0.425\nsquared_error = 0.448\nsamples = 387\nvalue = 11.006'),
#  Text(0.010912656123449422, 0.09375, 'X[4] <= 1.488\nsquared_error = 0.373\nsamples = 233\nvalue = 11.097'),
#  Text(0.010571635619591627, 0.03125, 'squared_error = 0.338\nsamples = 231\nvalue = 11.082'),
#  Text(0.011253676627307217, 0.03125, 'squared_error = 1.473\nsamples = 2\nvalue = 12.822'),
#  Text(0.0122767381388806, 0.09375, 'X[60] <= -1.669\nsquared_error = 0.531\nsamples = 154\nvalue = 10.869'),
#  Text(0.011935717635022805, 0.03125, 'squared_error = 3.022\nsamples = 3\nvalue = 9.362'),
#  Text(0.012617758642738395, 0.03125, 'squared_error = 0.436\nsamples = 151\nvalue = 10.899'),
#  Text(0.013299799650453983, 0.15625, 'X[44] <= -0.854\nsquared_error = 1.178\nsamples = 3\nvalue = 9.69'),
#  Text(0.012958779146596188, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.013640820154311778, 0.09375, 'squared_error = 0.0\nsamples = 2\nvalue = 8.923'),
#  Text(0.015857453429387443, 0.21875, 'X[2] <= -0.533\nsquared_error = 0.41\nsamples = 22\nvalue = 10.511'),
#  Text(0.015004902169742956, 0.15625, 'X[53] <= -0.796\nsquared_error = 0.192\nsamples = 20\nvalue = 10.655'),
#  Text(0.014322861162027366, 0.09375, 'X[58] <= 0.355\nsquared_error = 0.02\nsamples = 3\nvalue = 10.004'),
#  Text(0.013981840658169573, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.204'),
#  Text(0.014663881665885161, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 9.903'),
#  Text(0.015686943177458546, 0.09375, 'X[51] <= -0.965\nsquared_error = 0.134\nsamples = 17\nvalue = 10.77'),
#  Text(0.01534592267360075, 0.03125, 'squared_error = 0.073\nsamples = 4\nvalue = 10.298'),
#  Text(0.01602796368131634, 0.03125, 'squared_error = 0.063\nsamples = 13\nvalue = 10.915'),
#  Text(0.01671000468903193, 0.15625, 'X[50] <= -0.543\nsquared_error = 0.302\nsamples = 2\nvalue = 9.066'),
#  Text(0.016368984185174133, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.017051025192889722, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.517'),
#  Text(0.01909714821603649, 0.28125, 'X[61] <= 1.07\nsquared_error = 1.297\nsamples = 8\nvalue = 9.904'),
#  Text(0.018756127712178695, 0.21875, 'X[45] <= -0.312\nsquared_error = 0.19\nsamples = 7\nvalue = 10.306'),
#  Text(0.018074086704463106, 0.15625, 'X[52] <= 1.724\nsquared_error = 0.044\nsamples = 4\nvalue = 10.636'),
#  Text(0.017733066200605312, 0.09375, 'X[47] <= 1.111\nsquared_error = 0.011\nsamples = 3\nvalue = 10.745'),
#  Text(0.017392045696747516, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 10.82'),
#  Text(0.018074086704463106, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.0184151072083209, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.019438168719894285, 0.15625, 'X[49] <= -0.97\nsquared_error = 0.044\nsamples = 3\nvalue = 9.865'),
#  Text(0.01909714821603649, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.01977918922375208, 0.09375, 'X[0] <= -0.335\nsquared_error = 0.014\nsamples = 2\nvalue = 9.734'),
#  Text(0.019438168719894285, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 9.852'),
#  Text(0.02012020972760987, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.019438168719894285, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 7.09'),
#  Text(0.026173323671085724, 0.46875, 'X[49] <= -1.674\nsquared_error = 0.778\nsamples = 458\nvalue = 11.209'),
#  Text(0.02199582249882774, 0.40625, 'X[53] <= -1.306\nsquared_error = 10.296\nsamples = 11\nvalue = 9.896'),
#  Text(0.021654801994969948, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.022336843002685538, 0.34375, 'X[43] <= -0.212\nsquared_error = 0.554\nsamples = 10\nvalue = 10.886'),
#  Text(0.02148429174304105, 0.28125, 'X[48] <= 1.185\nsquared_error = 0.273\nsamples = 5\nvalue = 10.262'),
#  Text(0.021143271239183255, 0.21875, 'X[59] <= 0.598\nsquared_error = 0.01\nsamples = 4\nvalue = 10.005'),
#  Text(0.02080225073532546, 0.15625, 'X[15] <= -0.417\nsquared_error = 0.0\nsamples = 2\nvalue = 10.106'),
#  Text(0.02046123023146767, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.086'),
#  Text(0.021143271239183255, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.02148429174304105, 0.15625, 'squared_error = 0.0\nsamples = 2\nvalue = 9.903'),
#  Text(0.021825312246898845, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.02318939426233002, 0.28125, 'X[58] <= -0.148\nsquared_error = 0.057\nsamples = 5\nvalue = 11.509'),
#  Text(0.022507353254614434, 0.21875, 'X[52] <= 0.343\nsquared_error = 0.025\nsamples = 3\nvalue = 11.346'),
#  Text(0.022166332750756638, 0.15625, 'X[40] <= -1.783\nsquared_error = 0.002\nsamples = 2\nvalue = 11.455'),
#  Text(0.021825312246898845, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.503'),
#  Text(0.022507353254614434, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.022848373758472228, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 11.127'),
#  Text(0.02387143527004561, 0.21875, 'X[2] <= -1.127\nsquared_error = 0.003\nsamples = 2\nvalue = 11.754'),
#  Text(0.023530414766187818, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.024212455773903407, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.030350824843343706, 0.40625, 'X[4] <= -0.879\nsquared_error = 0.5\nsamples = 447\nvalue = 11.241'),
#  Text(0.026088068545121277, 0.34375, 'X[46] <= 1.683\nsquared_error = 0.449\nsamples = 191\nvalue = 11.08'),
#  Text(0.025406027537405687, 0.28125, 'X[50] <= -1.723\nsquared_error = 0.405\nsamples = 189\nvalue = 11.061'),
#  Text(0.02506500703354789, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 13.459'),
#  Text(0.02574704804126348, 0.21875, 'X[46] <= -1.556\nsquared_error = 0.376\nsamples = 188\nvalue = 11.049'),
#  Text(0.024894496781618994, 0.15625, 'X[32] <= 0.889\nsquared_error = 1.438\nsamples = 8\nvalue = 10.386'),
#  Text(0.0245534762777612, 0.09375, 'X[44] <= -0.022\nsquared_error = 0.102\nsamples = 7\nvalue = 10.825'),
#  Text(0.024212455773903407, 0.03125, 'squared_error = 0.06\nsamples = 3\nvalue = 11.135'),
#  Text(0.024894496781618994, 0.03125, 'squared_error = 0.008\nsamples = 4\nvalue = 10.593'),
#  Text(0.02523551728547679, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 7.313'),
#  Text(0.026599599300907967, 0.15625, 'X[22] <= 0.431\nsquared_error = 0.309\nsamples = 180\nvalue = 11.078'),
#  Text(0.025917558293192377, 0.09375, 'X[36] <= 0.839\nsquared_error = 0.288\nsamples = 166\nvalue = 11.119'),
#  Text(0.025576537789334584, 0.03125, 'squared_error = 0.247\nsamples = 162\nvalue = 11.14'),
#  Text(0.026258578797050174, 0.03125, 'squared_error = 1.23\nsamples = 4\nvalue = 10.272'),
#  Text(0.027281640308623557, 0.09375, 'X[60] <= -0.613\nsquared_error = 0.294\nsamples = 14\nvalue = 10.591'),
#  Text(0.02694061980476576, 0.03125, 'squared_error = 0.058\nsamples = 4\nvalue = 11.252'),
#  Text(0.02762266081248135, 0.03125, 'squared_error = 0.144\nsamples = 10\nvalue = 10.327'),
#  Text(0.026770109552836863, 0.28125, 'X[58] <= -0.367\nsquared_error = 1.402\nsamples = 2\nvalue = 12.879'),
#  Text(0.02642908904897907, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 14.063'),
#  Text(0.02711113005669466, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.03461358114156614, 0.34375, 'X[0] <= 1.959\nsquared_error = 0.504\nsamples = 256\nvalue = 11.361'),
#  Text(0.031544396606845986, 0.28125, 'X[56] <= -1.544\nsquared_error = 0.402\nsamples = 235\nvalue = 11.305'),
#  Text(0.029668783835628116, 0.21875, 'X[58] <= 1.434\nsquared_error = 3.292\nsamples = 12\nvalue = 10.646'),
#  Text(0.029327763331770323, 0.15625, 'X[52] <= 0.721\nsquared_error = 0.235\nsamples = 11\nvalue = 11.174'),
#  Text(0.028645722324054733, 0.09375, 'X[58] <= 0.113\nsquared_error = 0.122\nsamples = 7\nvalue = 10.921'),
#  Text(0.02830470182019694, 0.03125, 'squared_error = 0.007\nsamples = 4\nvalue = 11.198'),
#  Text(0.02898674282791253, 0.03125, 'squared_error = 0.037\nsamples = 3\nvalue = 10.552'),
#  Text(0.030009804339485913, 0.09375, 'X[59] <= -0.537\nsquared_error = 0.125\nsamples = 4\nvalue = 11.617'),
#  Text(0.029668783835628116, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.015'),
#  Text(0.030350824843343706, 0.03125, 'squared_error = 0.005\nsamples = 3\nvalue = 11.818'),
#  Text(0.030009804339485913, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.828'),
#  Text(0.03342000937806386, 0.21875, 'X[60] <= -1.267\nsquared_error = 0.222\nsamples = 223\nvalue = 11.34'),
#  Text(0.03205592736263268, 0.15625, 'X[43] <= -1.603\nsquared_error = 0.286\nsamples = 36\nvalue = 11.599'),
#  Text(0.03137388635491709, 0.09375, 'X[53] <= -0.947\nsquared_error = 0.0\nsamples = 3\nvalue = 12.6'),
#  Text(0.031032865851059296, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.578'),
#  Text(0.031714906858774886, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 12.612'),
#  Text(0.032737968370348265, 0.09375, 'X[0] <= 1.246\nsquared_error = 0.213\nsamples = 33\nvalue = 11.508'),
#  Text(0.03239694786649047, 0.03125, 'squared_error = 0.173\nsamples = 31\nvalue = 11.564'),
#  Text(0.03307898887420606, 0.03125, 'squared_error = 0.032\nsamples = 2\nvalue = 10.641'),
#  Text(0.03478409139349503, 0.15625, 'X[54] <= 1.668\nsquared_error = 0.194\nsamples = 187\nvalue = 11.29'),
#  Text(0.034102050385779445, 0.09375, 'X[2] <= -1.918\nsquared_error = 0.185\nsamples = 184\nvalue = 11.304'),
#  Text(0.03376102988192165, 0.03125, 'squared_error = 0.154\nsamples = 36\nvalue = 11.105'),
#  Text(0.03444307088963724, 0.03125, 'squared_error = 0.18\nsamples = 148\nvalue = 11.352'),
#  Text(0.035466132401210625, 0.09375, 'X[57] <= -0.44\nsquared_error = 0.049\nsamples = 3\nvalue = 10.44'),
#  Text(0.03512511189735283, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.03580715290506842, 0.03125, 'squared_error = -0.0\nsamples = 2\nvalue = 10.597'),
#  Text(0.037682765676286284, 0.28125, 'X[41] <= 0.346\nsquared_error = 1.206\nsamples = 21\nvalue = 11.998'),
#  Text(0.0368302144166418, 0.21875, 'X[59] <= 0.573\nsquared_error = 0.884\nsamples = 3\nvalue = 10.344'),
#  Text(0.036489193912784004, 0.15625, 'X[8] <= -0.3\nsquared_error = 0.302\nsamples = 2\nvalue = 9.76'),
#  Text(0.03614817340892621, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.0368302144166418, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 9.21'),
#  Text(0.0371712349204996, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.03853531693593077, 0.21875, 'X[55] <= -1.181\nsquared_error = 0.727\nsamples = 18\nvalue = 12.274'),
#  Text(0.037853275928215184, 0.15625, 'X[43] <= 1.617\nsquared_error = 0.048\nsamples = 2\nvalue = 14.006'),
#  Text(0.03751225542435739, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 13.786'),
#  Text(0.03819429643207298, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 14.226'),
#  Text(0.039217357943646364, 0.15625, 'X[44] <= 1.503\nsquared_error = 0.39\nsamples = 16\nvalue = 12.058'),
#  Text(0.03887633743978857, 0.09375, 'X[49] <= 0.863\nsquared_error = 0.197\nsamples = 15\nvalue = 11.94'),
#  Text(0.03853531693593077, 0.03125, 'squared_error = 0.075\nsamples = 12\nvalue = 12.112'),
#  Text(0.039217357943646364, 0.03125, 'squared_error = 0.096\nsamples = 3\nvalue = 11.256'),
#  Text(0.03955837844750416, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 13.816'),
#  Text(0.050854682637793594, 0.53125, 'X[43] <= -1.683\nsquared_error = 1.717\nsamples = 92\nvalue = 11.726'),
#  Text(0.0505136621339358, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.051195703141651394, 0.46875, 'X[2] <= -0.335\nsquared_error = 0.208\nsamples = 91\nvalue = 11.855'),
#  Text(0.047828125666055675, 0.40625, 'X[56] <= 0.192\nsquared_error = 0.197\nsamples = 74\nvalue = 11.939'),
#  Text(0.045099961635193316, 0.34375, 'X[53] <= -0.508\nsquared_error = 0.2\nsamples = 44\nvalue = 11.816'),
#  Text(0.04348011424186879, 0.28125, 'X[47] <= 1.589\nsquared_error = 0.181\nsamples = 16\nvalue = 12.055'),
#  Text(0.04228654247836651, 0.21875, 'X[1] <= -0.687\nsquared_error = 0.094\nsamples = 14\nvalue = 12.173'),
#  Text(0.04092246046293534, 0.15625, 'X[53] <= -1.147\nsquared_error = 0.044\nsamples = 7\nvalue = 11.928'),
#  Text(0.04024041945521974, 0.09375, 'X[44] <= 0.101\nsquared_error = 0.002\nsamples = 3\nvalue = 12.145'),
#  Text(0.03989939895136195, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.206'),
#  Text(0.04058143995907754, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 12.114'),
#  Text(0.04160450147065092, 0.09375, 'X[43] <= 0.414\nsquared_error = 0.014\nsamples = 4\nvalue = 11.766'),
#  Text(0.04126348096679313, 0.03125, 'squared_error = 0.001\nsamples = 2\nvalue = 11.884'),
#  Text(0.041945521974508716, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.648'),
#  Text(0.04365062449379769, 0.15625, 'X[44] <= 0.194\nsquared_error = 0.023\nsamples = 7\nvalue = 12.418'),
#  Text(0.0429685834860821, 0.09375, 'X[39] <= 1.755\nsquared_error = 0.004\nsamples = 2\nvalue = 12.219'),
#  Text(0.04262756298222431, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.155'),
#  Text(0.043309603989939896, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.283'),
#  Text(0.044332665501513276, 0.09375, 'X[53] <= -0.841\nsquared_error = 0.009\nsamples = 5\nvalue = 12.498'),
#  Text(0.04399164499765548, 0.03125, 'squared_error = 0.004\nsamples = 3\nvalue = 12.434'),
#  Text(0.044673686005371076, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 12.595'),
#  Text(0.044673686005371076, 0.21875, 'X[58] <= 0.243\nsquared_error = 0.004\nsamples = 2\nvalue = 11.223'),
#  Text(0.044332665501513276, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.04501470650922887, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.04671980902851784, 0.28125, 'X[47] <= -1.372\nsquared_error = 0.159\nsamples = 28\nvalue = 11.679'),
#  Text(0.04603776802080225, 0.21875, 'X[53] <= 0.518\nsquared_error = 0.019\nsamples = 2\nvalue = 10.959'),
#  Text(0.045696747516944455, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.04637878852466004, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.097'),
#  Text(0.04740185003623343, 0.21875, 'X[49] <= 1.602\nsquared_error = 0.127\nsamples = 26\nvalue = 11.735'),
#  Text(0.047060829532375635, 0.15625, 'X[48] <= -0.692\nsquared_error = 0.1\nsamples = 25\nvalue = 11.77'),
#  Text(0.04637878852466004, 0.09375, 'X[52] <= -0.68\nsquared_error = 0.066\nsamples = 10\nvalue = 11.571'),
#  Text(0.04603776802080225, 0.03125, 'squared_error = 0.001\nsamples = 3\nvalue = 11.872'),
#  Text(0.04671980902851784, 0.03125, 'squared_error = 0.039\nsamples = 7\nvalue = 11.442'),
#  Text(0.04774287054009122, 0.09375, 'X[59] <= 1.323\nsquared_error = 0.078\nsamples = 15\nvalue = 11.902'),
#  Text(0.04740185003623343, 0.03125, 'squared_error = 0.041\nsamples = 13\nvalue = 11.981'),
#  Text(0.048083891043949015, 0.03125, 'squared_error = 0.015\nsamples = 2\nvalue = 11.389'),
#  Text(0.04774287054009122, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 10.859'),
#  Text(0.05055628969691803, 0.34375, 'X[49] <= -0.88\nsquared_error = 0.138\nsamples = 30\nvalue = 12.12'),
#  Text(0.049447973059380194, 0.28125, 'X[44] <= -1.601\nsquared_error = 0.103\nsamples = 7\nvalue = 11.769'),
#  Text(0.0491069525555224, 0.21875, 'squared_error = 0.0\nsamples = 2\nvalue = 11.29'),
#  Text(0.04978899356323799, 0.21875, 'X[43] <= 1.373\nsquared_error = 0.015\nsamples = 5\nvalue = 11.96'),
#  Text(0.049447973059380194, 0.15625, 'X[45] <= 1.338\nsquared_error = 0.003\nsamples = 4\nvalue = 12.017'),
#  Text(0.0491069525555224, 0.09375, 'X[46] <= 0.001\nsquared_error = 0.001\nsamples = 3\nvalue = 11.985'),
#  Text(0.04876593205166461, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.97'),
#  Text(0.049447973059380194, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.014'),
#  Text(0.04978899356323799, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.112'),
#  Text(0.05013001406709578, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.05166460633445586, 0.28125, 'X[47] <= -1.464\nsquared_error = 0.1\nsamples = 23\nvalue = 12.226'),
#  Text(0.05132358583059807, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 13.106'),
#  Text(0.052005626838313654, 0.21875, 'X[62] <= 0.202\nsquared_error = 0.068\nsamples = 22\nvalue = 12.186'),
#  Text(0.05115307557866917, 0.15625, 'X[59] <= -0.933\nsquared_error = 0.041\nsamples = 14\nvalue = 12.306'),
#  Text(0.05047103457095358, 0.09375, 'X[0] <= -0.335\nsquared_error = 0.007\nsamples = 3\nvalue = 12.574'),
#  Text(0.05013001406709578, 0.03125, 'squared_error = 0.001\nsamples = 2\nvalue = 12.515'),
#  Text(0.050812055074811374, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.692'),
#  Text(0.051835116586384754, 0.09375, 'X[51] <= 1.329\nsquared_error = 0.025\nsamples = 11\nvalue = 12.233'),
#  Text(0.05149409608252696, 0.03125, 'squared_error = 0.014\nsamples = 9\nvalue = 12.288'),
#  Text(0.052176137090242554, 0.03125, 'squared_error = -0.0\nsamples = 2\nvalue = 11.983'),
#  Text(0.05285817809795814, 0.15625, 'X[54] <= -1.146\nsquared_error = 0.046\nsamples = 8\nvalue = 11.977'),
#  Text(0.05251715759410035, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.053199198601815934, 0.09375, 'X[60] <= 0.965\nsquared_error = 0.017\nsamples = 7\nvalue = 12.043'),
#  Text(0.05285817809795814, 0.03125, 'squared_error = 0.004\nsamples = 5\nvalue = 11.969'),
#  Text(0.05354021910567373, 0.03125, 'squared_error = 0.001\nsamples = 2\nvalue = 12.23'),
#  Text(0.05456328061724711, 0.40625, 'X[61] <= -0.479\nsquared_error = 0.093\nsamples = 17\nvalue = 11.49'),
#  Text(0.05285817809795814, 0.34375, 'X[58] <= -0.724\nsquared_error = 0.013\nsamples = 5\nvalue = 11.126'),
#  Text(0.05251715759410035, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.053199198601815934, 0.28125, 'X[1] <= -0.957\nsquared_error = 0.0\nsamples = 4\nvalue = 11.07'),
#  Text(0.05285817809795814, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 11.035'),
#  Text(0.05354021910567373, 0.21875, 'squared_error = 0.0\nsamples = 3\nvalue = 11.082'),
#  Text(0.056268383136536086, 0.34375, 'X[58] <= 0.388\nsquared_error = 0.049\nsamples = 12\nvalue = 11.642'),
#  Text(0.05456328061724711, 0.28125, 'X[49] <= -0.886\nsquared_error = 0.033\nsamples = 7\nvalue = 11.78'),
#  Text(0.05422226011338932, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 12.128'),
#  Text(0.054904301121104906, 0.21875, 'X[45] <= -0.904\nsquared_error = 0.014\nsamples = 6\nvalue = 11.722'),
#  Text(0.05422226011338932, 0.15625, 'X[50] <= -1.215\nsquared_error = 0.002\nsamples = 2\nvalue = 11.561'),
#  Text(0.05388123960953152, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.05456328061724711, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.05558634212882049, 0.15625, 'X[62] <= 0.016\nsquared_error = 0.001\nsamples = 4\nvalue = 11.803'),
#  Text(0.0552453216249627, 0.09375, 'X[47] <= 0.035\nsquared_error = 0.0\nsamples = 2\nvalue = 11.831'),
#  Text(0.054904301121104906, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.05558634212882049, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.05592736263267829, 0.09375, 'squared_error = -0.0\nsamples = 2\nvalue = 11.775'),
#  Text(0.05797348565582506, 0.28125, 'X[57] <= -0.536\nsquared_error = 0.007\nsamples = 5\nvalue = 11.448'),
#  Text(0.057291444648109466, 0.21875, 'X[57] <= -0.668\nsquared_error = 0.001\nsamples = 3\nvalue = 11.509'),
#  Text(0.05695042414425167, 0.15625, 'X[53] <= -0.676\nsquared_error = 0.0\nsamples = 2\nvalue = 11.533'),
#  Text(0.05660940364039388, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.533'),
#  Text(0.057291444648109466, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.533'),
#  Text(0.05763246515196726, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.058655526663540646, 0.21875, 'X[41] <= 0.346\nsquared_error = 0.003\nsamples = 2\nvalue = 11.357'),
#  Text(0.05831450615968285, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.306'),
#  Text(0.05899654716739844, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.08101634767040368, 0.59375, 'X[53] <= 1.719\nsquared_error = 0.807\nsamples = 1858\nvalue = 11.346'),
#  Text(0.07208853744831407, 0.53125, 'X[1] <= -0.91\nsquared_error = 0.739\nsamples = 1853\nvalue = 11.352'),
#  Text(0.06372820665842534, 0.46875, 'X[58] <= 1.333\nsquared_error = 6.737\nsamples = 19\nvalue = 10.327'),
#  Text(0.06338718615456754, 0.40625, 'X[37] <= 1.776\nsquared_error = 0.857\nsamples = 18\nvalue = 10.901'),
#  Text(0.06232149708001194, 0.34375, 'X[54] <= 1.541\nsquared_error = 0.293\nsamples = 14\nvalue = 11.282'),
#  Text(0.061213180442474105, 0.28125, 'X[54] <= 0.686\nsquared_error = 0.201\nsamples = 12\nvalue = 11.422'),
#  Text(0.060019608678971825, 0.21875, 'X[7] <= -1.977\nsquared_error = 0.059\nsamples = 9\nvalue = 11.221'),
#  Text(0.05967858817511403, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.06036062918282962, 0.15625, 'X[57] <= 0.672\nsquared_error = 0.024\nsamples = 8\nvalue = 11.152'),
#  Text(0.05967858817511403, 0.09375, 'X[47] <= -0.462\nsquared_error = 0.005\nsamples = 5\nvalue = 11.043'),
#  Text(0.05933756767125623, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.127'),
#  Text(0.060019608678971825, 0.03125, 'squared_error = 0.0\nsamples = 3\nvalue = 10.987'),
#  Text(0.061042670190545205, 0.09375, 'X[44] <= -1.066\nsquared_error = 0.002\nsamples = 3\nvalue = 11.334'),
#  Text(0.06070164968668741, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.396'),
#  Text(0.061383690694403, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.302'),
#  Text(0.062406752205976385, 0.21875, 'X[54] <= 1.191\nsquared_error = 0.145\nsamples = 3\nvalue = 12.023'),
#  Text(0.06206573170211859, 0.15625, 'X[10] <= -2.45\nsquared_error = 0.023\nsamples = 2\nvalue = 12.279'),
#  Text(0.0617247111982608, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.128'),
#  Text(0.062406752205976385, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 12.429'),
#  Text(0.06274777270983418, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.06342981371754977, 0.28125, 'X[55] <= 0.142\nsquared_error = 0.017\nsamples = 2\nvalue = 10.44'),
#  Text(0.06308879321369197, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 10.571'),
#  Text(0.06377083422140756, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.06445287522912316, 0.34375, 'X[0] <= -0.383\nsquared_error = 0.549\nsamples = 4\nvalue = 9.569'),
#  Text(0.06411185472526536, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 8.294'),
#  Text(0.06479389573298094, 0.28125, 'X[61] <= 0.534\nsquared_error = 0.009\nsamples = 3\nvalue = 9.994'),
#  Text(0.06445287522912316, 0.21875, 'X[55] <= -0.502\nsquared_error = 0.001\nsamples = 2\nvalue = 9.928'),
#  Text(0.06411185472526536, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 9.952'),
#  Text(0.06479389573298094, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 9.903'),
#  Text(0.06513491623683874, 0.21875, 'squared_error = -0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.06406922716228314, 0.40625, 'squared_error = -0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.08044886823820283, 0.46875, 'X[44] <= 1.679\nsquared_error = 0.666\nsamples = 1834\nvalue = 11.363'),
#  Text(0.07331940832942581, 0.40625, 'X[4] <= -0.879\nsquared_error = 0.533\nsamples = 1795\nvalue = 11.378'),
#  Text(0.06880088665331004, 0.34375, 'X[17] <= -6.151\nsquared_error = 0.694\nsamples = 789\nvalue = 11.283'),
#  Text(0.06615797774841212, 0.28125, 'X[47] <= 1.579\nsquared_error = 14.287\nsamples = 8\nvalue = 9.896'),
#  Text(0.06581695724455433, 0.21875, 'X[52] <= 1.496\nsquared_error = 0.339\nsamples = 7\nvalue = 11.31'),
#  Text(0.06547593674069653, 0.15625, 'X[46] <= 0.39\nsquared_error = 0.123\nsamples = 6\nvalue = 11.507'),
#  Text(0.06479389573298094, 0.09375, 'X[59] <= 0.216\nsquared_error = 0.02\nsamples = 3\nvalue = 11.183'),
#  Text(0.06445287522912316, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.385'),
#  Text(0.06513491623683874, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.082'),
#  Text(0.06615797774841212, 0.09375, 'X[46] <= 1.304\nsquared_error = 0.015\nsamples = 3\nvalue = 11.831'),
#  Text(0.06581695724455433, 0.03125, 'squared_error = -0.0\nsamples = 2\nvalue = 11.918'),
#  Text(0.06649899825226992, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.657'),
#  Text(0.06615797774841212, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.06649899825226992, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.07144379555820794, 0.28125, 'X[57] <= 1.704\nsquared_error = 0.535\nsamples = 781\nvalue = 11.297'),
#  Text(0.06956818278699006, 0.21875, 'X[59] <= -0.054\nsquared_error = 0.47\nsamples = 775\nvalue = 11.308'),
#  Text(0.06820410077155889, 0.15625, 'X[1] <= -0.734\nsquared_error = 0.337\nsamples = 379\nvalue = 11.403'),
#  Text(0.0675220597638433, 0.09375, 'X[61] <= 0.515\nsquared_error = 0.218\nsamples = 48\nvalue = 11.104'),
#  Text(0.0671810392599855, 0.03125, 'squared_error = 0.204\nsamples = 32\nvalue = 10.964'),
#  Text(0.06786308026770109, 0.03125, 'squared_error = 0.13\nsamples = 16\nvalue = 11.384'),
#  Text(0.06888614177927448, 0.09375, 'X[1] <= -0.006\nsquared_error = 0.339\nsamples = 331\nvalue = 11.446'),
#  Text(0.06854512127541669, 0.03125, 'squared_error = 0.3\nsamples = 287\nvalue = 11.495'),
#  Text(0.06922716228313228, 0.03125, 'squared_error = 0.478\nsamples = 44\nvalue = 11.127'),
#  Text(0.07093226480242125, 0.15625, 'X[31] <= -1.772\nsquared_error = 0.58\nsamples = 396\nvalue = 11.218'),
#  Text(0.07025022379470566, 0.09375, 'X[61] <= 1.305\nsquared_error = 8.93\nsamples = 3\nvalue = 9.325'),
#  Text(0.06990920329084786, 0.03125, 'squared_error = 0.044\nsamples = 2\nvalue = 11.435'),
#  Text(0.07059124429856345, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.106'),
#  Text(0.07161430581013684, 0.09375, 'X[49] <= -1.407\nsquared_error = 0.489\nsamples = 393\nvalue = 11.232'),
#  Text(0.07127328530627904, 0.03125, 'squared_error = 0.52\nsamples = 38\nvalue = 10.921'),
#  Text(0.07195532631399464, 0.03125, 'squared_error = 0.474\nsamples = 355\nvalue = 11.265'),
#  Text(0.07331940832942581, 0.21875, 'X[62] <= -1.213\nsquared_error = 6.933\nsamples = 6\nvalue = 9.896'),
#  Text(0.07297838782556801, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.248'),
#  Text(0.0736604288332836, 0.15625, 'X[6] <= -0.597\nsquared_error = 0.665\nsamples = 5\nvalue = 11.026'),
#  Text(0.07297838782556801, 0.09375, 'X[53] <= 0.143\nsquared_error = 0.003\nsamples = 2\nvalue = 11.866'),
#  Text(0.07263736732171022, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.07331940832942581, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.918'),
#  Text(0.0743424698409992, 0.09375, 'X[19] <= 0.789\nsquared_error = 0.322\nsamples = 3\nvalue = 10.466'),
#  Text(0.0740014493371414, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 9.68'),
#  Text(0.07468349034485698, 0.03125, 'squared_error = 0.021\nsamples = 2\nvalue = 10.858'),
#  Text(0.07783793000554158, 0.34375, 'X[0] <= -0.379\nsquared_error = 0.394\nsamples = 1006\nvalue = 11.452'),
#  Text(0.07604757236028817, 0.28125, 'X[52] <= 1.574\nsquared_error = 3.968\nsamples = 36\nvalue = 10.953'),
#  Text(0.07570655185643037, 0.21875, 'X[49] <= 1.495\nsquared_error = 0.555\nsamples = 35\nvalue = 11.266'),
#  Text(0.07536553135257257, 0.15625, 'X[45] <= -1.664\nsquared_error = 0.343\nsamples = 34\nvalue = 11.347'),
#  Text(0.07502451084871478, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 13.521'),
#  Text(0.07570655185643037, 0.09375, 'X[51] <= -0.154\nsquared_error = 0.206\nsamples = 33\nvalue = 11.281'),
#  Text(0.07536553135257257, 0.03125, 'squared_error = 0.117\nsamples = 14\nvalue = 10.93'),
#  Text(0.07604757236028817, 0.03125, 'squared_error = 0.113\nsamples = 19\nvalue = 11.54'),
#  Text(0.07604757236028817, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 8.517'),
#  Text(0.07638859286414595, 0.21875, 'squared_error = -0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.07962828765079501, 0.28125, 'X[19] <= 0.789\nsquared_error = 0.251\nsamples = 970\nvalue = 11.47'),
#  Text(0.07741165437571934, 0.21875, 'X[31] <= -1.772\nsquared_error = 0.238\nsamples = 471\nvalue = 11.57'),
#  Text(0.07707063387186154, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 8.517'),
#  Text(0.07775267487957714, 0.15625, 'X[52] <= -1.635\nsquared_error = 0.219\nsamples = 470\nvalue = 11.577'),
#  Text(0.07707063387186154, 0.09375, 'X[41] <= 0.346\nsquared_error = 0.217\nsamples = 19\nvalue = 11.966'),
#  Text(0.07672961336800375, 0.03125, 'squared_error = 0.072\nsamples = 13\nvalue = 11.768'),
#  Text(0.07741165437571934, 0.03125, 'squared_error = 0.263\nsamples = 6\nvalue = 12.394'),
#  Text(0.07843471588729273, 0.09375, 'X[39] <= 4.77\nsquared_error = 0.212\nsamples = 451\nvalue = 11.56'),
#  Text(0.07809369538343493, 0.03125, 'squared_error = 0.206\nsamples = 450\nvalue = 11.556'),
#  Text(0.07877573639115051, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 13.305'),
#  Text(0.08184492092587067, 0.21875, 'X[6] <= -1.58\nsquared_error = 0.245\nsamples = 499\nvalue = 11.376'),
#  Text(0.08048083891043949, 0.15625, 'X[55] <= 1.576\nsquared_error = 0.272\nsamples = 200\nvalue = 11.256'),
#  Text(0.0797987979027239, 0.09375, 'X[58] <= 1.577\nsquared_error = 0.233\nsamples = 189\nvalue = 11.291'),
#  Text(0.0794577773988661, 0.03125, 'squared_error = 0.225\nsamples = 184\nvalue = 11.31'),
#  Text(0.0801398184065817, 0.03125, 'squared_error = 0.06\nsamples = 5\nvalue = 10.602'),
#  Text(0.08116287991815507, 0.09375, 'X[57] <= -0.883\nsquared_error = 0.551\nsamples = 11\nvalue = 10.65'),
#  Text(0.08082185941429729, 0.03125, 'squared_error = 0.152\nsamples = 3\nvalue = 9.747'),
#  Text(0.08150390042201287, 0.03125, 'squared_error = 0.28\nsamples = 8\nvalue = 10.989'),
#  Text(0.08320900294130185, 0.15625, 'X[6] <= -0.008\nsquared_error = 0.212\nsamples = 299\nvalue = 11.456'),
#  Text(0.08252696193358626, 0.09375, 'X[60] <= -0.865\nsquared_error = 0.256\nsamples = 19\nvalue = 11.845'),
#  Text(0.08218594142972846, 0.03125, 'squared_error = 0.158\nsamples = 7\nvalue = 11.371'),
#  Text(0.08286798243744405, 0.03125, 'squared_error = 0.106\nsamples = 12\nvalue = 12.121'),
#  Text(0.08389104394901743, 0.09375, 'X[50] <= -1.716\nsquared_error = 0.198\nsamples = 280\nvalue = 11.429'),
#  Text(0.08355002344515965, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 9.852'),
#  Text(0.08423206445287523, 0.03125, 'squared_error = 0.189\nsamples = 279\nvalue = 11.435'),
#  Text(0.08757832814697984, 0.40625, 'X[53] <= 1.52\nsquared_error = 6.345\nsamples = 39\nvalue = 10.684'),
#  Text(0.08623555991303977, 0.34375, 'X[59] <= -1.391\nsquared_error = 0.187\nsamples = 36\nvalue = 11.269'),
#  Text(0.08457308495673302, 0.28125, 'X[55] <= 0.679\nsquared_error = 0.064\nsamples = 4\nvalue = 10.535'),
#  Text(0.08423206445287523, 0.21875, 'X[60] <= -0.13\nsquared_error = 0.011\nsamples = 3\nvalue = 10.671'),
#  Text(0.08389104394901743, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.08457308495673302, 0.15625, 'squared_error = -0.0\nsamples = 2\nvalue = 10.597'),
#  Text(0.08491410546059082, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.08789803486934653, 0.28125, 'X[0] <= -0.348\nsquared_error = 0.127\nsamples = 32\nvalue = 11.36'),
#  Text(0.0859371669721642, 0.21875, 'X[50] <= 0.296\nsquared_error = 0.056\nsamples = 8\nvalue = 11.084'),
#  Text(0.08525512596444862, 0.15625, 'X[57] <= -1.077\nsquared_error = 0.024\nsamples = 5\nvalue = 11.222'),
#  Text(0.08491410546059082, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.0855961464683064, 0.09375, 'X[46] <= -0.207\nsquared_error = 0.001\nsamples = 4\nvalue = 11.299'),
#  Text(0.08525512596444862, 0.03125, 'squared_error = 0.0\nsamples = 3\nvalue = 11.281'),
#  Text(0.0859371669721642, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.08661920797987979, 0.15625, 'X[58] <= -0.563\nsquared_error = 0.023\nsamples = 3\nvalue = 10.854'),
#  Text(0.08627818747602199, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.645'),
#  Text(0.08696022848373758, 0.09375, 'X[4] <= -0.287\nsquared_error = 0.002\nsamples = 2\nvalue = 10.959'),
#  Text(0.08661920797987979, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.08730124898759538, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.08985890276652883, 0.21875, 'X[46] <= 1.49\nsquared_error = 0.117\nsamples = 24\nvalue = 11.453'),
#  Text(0.08900635150688435, 0.15625, 'X[46] <= 0.632\nsquared_error = 0.1\nsamples = 21\nvalue = 11.514'),
#  Text(0.08832431049916876, 0.09375, 'X[60] <= -0.354\nsquared_error = 0.081\nsamples = 16\nvalue = 11.415'),
#  Text(0.08798328999531096, 0.03125, 'squared_error = 0.043\nsamples = 7\nvalue = 11.619'),
#  Text(0.08866533100302655, 0.03125, 'squared_error = 0.052\nsamples = 9\nvalue = 11.257'),
#  Text(0.08968839251459994, 0.09375, 'X[47] <= 0.518\nsquared_error = 0.028\nsamples = 5\nvalue = 11.832'),
#  Text(0.08934737201074215, 0.03125, 'squared_error = 0.008\nsamples = 2\nvalue = 11.649'),
#  Text(0.09002941301845774, 0.03125, 'squared_error = 0.004\nsamples = 3\nvalue = 11.954'),
#  Text(0.09071145402617332, 0.15625, 'X[45] <= 0.444\nsquared_error = 0.021\nsamples = 3\nvalue = 11.019'),
#  Text(0.09037043352231552, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.09105247453003112, 0.09375, 'X[55] <= 0.178\nsquared_error = 0.001\nsamples = 2\nvalue = 11.119'),
#  Text(0.09071145402617332, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.09139349503388891, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.0889210963809199, 0.34375, 'X[58] <= 0.506\nsquared_error = 26.899\nsamples = 3\nvalue = 3.667'),
#  Text(0.08858007587706211, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.0892621168847777, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.08994415789249328, 0.53125, 'X[43] <= 0.992\nsquared_error = 19.978\nsamples = 5\nvalue = 8.92'),
#  Text(0.0896031373886355, 0.46875, 'X[15] <= -0.417\nsquared_error = 0.108\nsamples = 4\nvalue = 11.15'),
#  Text(0.0892621168847777, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.08994415789249328, 0.40625, 'X[46] <= -0.783\nsquared_error = 0.012\nsamples = 3\nvalue = 10.968'),
#  Text(0.0896031373886355, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.09028517839635108, 0.34375, 'X[43] <= 0.291\nsquared_error = 0.002\nsamples = 2\nvalue = 11.042'),
#  Text(0.08994415789249328, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.09062619890020887, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.09028517839635108, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.10924911547806812, 0.65625, 'X[52] <= -1.729\nsquared_error = 0.573\nsamples = 2193\nvalue = 11.557'),
#  Text(0.09763843301078477, 0.59375, 'X[5] <= -0.311\nsquared_error = 11.753\nsamples = 2\nvalue = 8.033'),
#  Text(0.09729741250692697, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 4.605'),
#  Text(0.09797945351464257, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.12085979794535147, 0.59375, 'X[28] <= 0.462\nsquared_error = 0.552\nsamples = 2191\nvalue = 11.56'),
#  Text(0.09866149452235816, 0.53125, 'X[60] <= -1.714\nsquared_error = 0.595\nsamples = 1750\nvalue = 11.51'),
#  Text(0.09173451553774671, 0.46875, 'X[4] <= -2.062\nsquared_error = 18.414\nsamples = 6\nvalue = 9.584'),
#  Text(0.09139349503388891, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.0920755360416045, 0.40625, 'X[61] <= 1.187\nsquared_error = 0.053\nsamples = 5\nvalue = 11.501'),
#  Text(0.09173451553774671, 0.34375, 'X[52] <= -1.269\nsquared_error = 0.012\nsamples = 4\nvalue = 11.396'),
#  Text(0.09139349503388891, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.562'),
#  Text(0.0920755360416045, 0.28125, 'X[57] <= 0.471\nsquared_error = 0.003\nsamples = 3\nvalue = 11.341'),
#  Text(0.09173451553774671, 0.21875, 'X[38] <= 1.116\nsquared_error = 0.001\nsamples = 2\nvalue = 11.379'),
#  Text(0.09139349503388891, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.0920755360416045, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.0924165565454623, 0.21875, 'squared_error = -0.0\nsamples = 1\nvalue = 11.264'),
#  Text(0.0924165565454623, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.918'),
#  Text(0.10558847350696961, 0.46875, 'X[3] <= -1.824\nsquared_error = 0.521\nsamples = 1744\nvalue = 11.517'),
#  Text(0.09736135385140031, 0.40625, 'X[62] <= 1.575\nsquared_error = 2.13\nsamples = 22\nvalue = 10.589'),
#  Text(0.09702033334754252, 0.34375, 'X[42] <= -1.084\nsquared_error = 0.732\nsamples = 21\nvalue = 10.85'),
#  Text(0.09446267956860906, 0.28125, 'X[46] <= -1.248\nsquared_error = 0.564\nsamples = 16\nvalue = 10.581'),
#  Text(0.09309859755317788, 0.21875, 'X[8] <= 1.162\nsquared_error = 0.3\nsamples = 3\nvalue = 11.764'),
#  Text(0.09275757704932008, 0.15625, 'X[10] <= -2.45\nsquared_error = 0.017\nsamples = 2\nvalue = 11.384'),
#  Text(0.0924165565454623, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.254'),
#  Text(0.09309859755317788, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.09343961805703568, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 12.525'),
#  Text(0.09582676158404024, 0.21875, 'X[50] <= -0.273\nsquared_error = 0.227\nsamples = 13\nvalue = 10.308'),
#  Text(0.09446267956860906, 0.15625, 'X[57] <= -1.492\nsquared_error = 0.064\nsamples = 4\nvalue = 10.819'),
#  Text(0.09378063856089347, 0.09375, 'X[61] <= 0.343\nsquared_error = 0.026\nsamples = 2\nvalue = 10.596'),
#  Text(0.09343961805703568, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.434'),
#  Text(0.09412165906475127, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.758'),
#  Text(0.09514472057632466, 0.09375, 'X[56] <= 0.604\nsquared_error = 0.002\nsamples = 2\nvalue = 11.042'),
#  Text(0.09480370007246686, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.09548574108018244, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.09719084359947142, 0.15625, 'X[52] <= -0.768\nsquared_error = 0.133\nsamples = 9\nvalue = 10.081'),
#  Text(0.09650880259175583, 0.09375, 'X[7] <= -1.977\nsquared_error = 0.051\nsamples = 2\nvalue = 10.689'),
#  Text(0.09616778208789803, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.09684982309561363, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.463'),
#  Text(0.097872884607187, 0.09375, 'X[0] <= -0.329\nsquared_error = 0.02\nsamples = 7\nvalue = 9.908'),
#  Text(0.09753186410332922, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.0982139051110448, 0.03125, 'squared_error = 0.007\nsamples = 6\nvalue = 9.957'),
#  Text(0.09957798712647598, 0.28125, 'X[50] <= 0.013\nsquared_error = 0.298\nsamples = 5\nvalue = 11.711'),
#  Text(0.09923696662261819, 0.21875, 'X[1] <= -0.681\nsquared_error = 0.119\nsamples = 4\nvalue = 11.486'),
#  Text(0.09889594611876039, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 10.933'),
#  Text(0.09957798712647598, 0.15625, 'X[54] <= 0.446\nsquared_error = 0.023\nsamples = 3\nvalue = 11.67'),
#  Text(0.09923696662261819, 0.09375, 'X[17] <= 0.5\nsquared_error = 0.005\nsamples = 2\nvalue = 11.769'),
#  Text(0.09889594611876039, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.842'),
#  Text(0.09957798712647598, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.09991900763033378, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 11.472'),
#  Text(0.09991900763033378, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 12.612'),
#  Text(0.09770237435525811, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.106'),
#  Text(0.11381559316253889, 0.40625, 'X[6] <= -1.58\nsquared_error = 0.489\nsamples = 1722\nvalue = 11.529'),
#  Text(0.10742145871520525, 0.34375, 'X[19] <= 0.789\nsquared_error = 0.418\nsamples = 585\nvalue = 11.402'),
#  Text(0.10401125367662731, 0.28125, 'X[50] <= 1.677\nsquared_error = 0.426\nsamples = 322\nvalue = 11.528'),
#  Text(0.10264717166119613, 0.21875, 'X[29] <= 1.748\nsquared_error = 0.305\nsamples = 319\nvalue = 11.546'),
#  Text(0.10128308964576495, 0.15625, 'X[53] <= 0.563\nsquared_error = 0.276\nsamples = 297\nvalue = 11.512'),
#  Text(0.10060104863804936, 0.09375, 'X[51] <= 1.689\nsquared_error = 0.276\nsamples = 202\nvalue = 11.449'),
#  Text(0.10026002813419156, 0.03125, 'squared_error = 0.253\nsamples = 200\nvalue = 11.461'),
#  Text(0.10094206914190716, 0.03125, 'squared_error = 1.015\nsamples = 2\nvalue = 10.218'),
#  Text(0.10196513065348053, 0.09375, 'X[2] <= -1.522\nsquared_error = 0.249\nsamples = 95\nvalue = 11.646'),
#  Text(0.10162411014962275, 0.03125, 'squared_error = 0.339\nsamples = 17\nvalue = 12.059'),
#  Text(0.10230615115733833, 0.03125, 'squared_error = 0.184\nsamples = 78\nvalue = 11.557'),
#  Text(0.10401125367662731, 0.15625, 'X[60] <= -0.084\nsquared_error = 0.485\nsamples = 22\nvalue = 11.997'),
#  Text(0.10332921266891172, 0.09375, 'X[22] <= 0.431\nsquared_error = 0.201\nsamples = 11\nvalue = 11.498'),
#  Text(0.10298819216505392, 0.03125, 'squared_error = 0.089\nsamples = 7\nvalue = 11.774'),
#  Text(0.10367023317276951, 0.03125, 'squared_error = 0.032\nsamples = 4\nvalue = 11.015'),
#  Text(0.1046932946843429, 0.09375, 'X[4] <= 0.897\nsquared_error = 0.271\nsamples = 11\nvalue = 12.495'),
#  Text(0.10435227418048511, 0.03125, 'squared_error = 0.037\nsamples = 10\nvalue = 12.341'),
#  Text(0.1050343151882007, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 14.036'),
#  Text(0.10537533569205848, 0.21875, 'X[44] <= -1.374\nsquared_error = 9.567\nsamples = 3\nvalue = 9.614'),
#  Text(0.1050343151882007, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.298'),
#  Text(0.10571635619591628, 0.15625, 'X[27] <= 0.755\nsquared_error = 0.38\nsamples = 2\nvalue = 11.772'),
# ...
#  Text(0.20120209727609872, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 12.429'),
#  Text(0.20188413828381432, 0.15625, 'X[55] <= 0.936\nsquared_error = 0.0\nsamples = 3\nvalue = 12.309'),
#  Text(0.2015431177799565, 0.09375, 'squared_error = 0.0\nsamples = 2\nvalue = 12.301'),
#  Text(0.2022251587876721, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.324'),
#  Text(0.2029071997953877, 0.21875, 'X[4] <= 0.305\nsquared_error = 0.008\nsamples = 2\nvalue = 12.748'),
#  Text(0.2025661792915299, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 12.66'),
#  Text(0.2032482202992455, 0.15625, 'squared_error = -0.0\nsamples = 1\nvalue = 12.835'),
#  Text(0.20725521121957458, 0.40625, 'X[58] <= 1.531\nsquared_error = 5.91\nsamples = 29\nvalue = 11.125'),
#  Text(0.2069141907157168, 0.34375, 'X[45] <= -1.081\nsquared_error = 1.543\nsamples = 28\nvalue = 11.522'),
#  Text(0.20657317021185898, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.521'),
#  Text(0.20725521121957458, 0.28125, 'X[53] <= 0.681\nsquared_error = 0.218\nsamples = 27\nvalue = 11.745'),
#  Text(0.20529434332239227, 0.21875, 'X[57] <= -0.223\nsquared_error = 0.145\nsamples = 19\nvalue = 11.917'),
#  Text(0.20393026130696107, 0.15625, 'X[0] <= -0.338\nsquared_error = 0.136\nsamples = 6\nvalue = 12.237'),
#  Text(0.2032482202992455, 0.09375, 'X[4] <= -0.879\nsquared_error = 0.041\nsamples = 3\nvalue = 12.551'),
#  Text(0.2029071997953877, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.835'),
#  Text(0.20358924080310328, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 12.409'),
#  Text(0.20461230231467667, 0.09375, 'X[48] <= -0.581\nsquared_error = 0.035\nsamples = 3\nvalue = 11.923'),
#  Text(0.20427128181081888, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.155'),
#  Text(0.20495332281853446, 0.03125, 'squared_error = 0.012\nsamples = 2\nvalue = 11.807'),
#  Text(0.20665842533782344, 0.15625, 'X[46] <= -0.04\nsquared_error = 0.079\nsamples = 13\nvalue = 11.769'),
#  Text(0.20597638433010784, 0.09375, 'X[5] <= -0.311\nsquared_error = 0.027\nsamples = 3\nvalue = 12.114'),
#  Text(0.20563536382625006, 0.03125, 'squared_error = 0.008\nsamples = 2\nvalue = 12.01'),
#  Text(0.20631740483396563, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 12.324'),
#  Text(0.20734046634553902, 0.09375, 'X[61] <= 1.673\nsquared_error = 0.049\nsamples = 10\nvalue = 11.666'),
#  Text(0.20699944584168123, 0.03125, 'squared_error = 0.001\nsamples = 3\nvalue = 11.369'),
#  Text(0.20768148684939683, 0.03125, 'squared_error = 0.015\nsamples = 7\nvalue = 11.793'),
#  Text(0.20921607911675688, 0.21875, 'X[44] <= -1.171\nsquared_error = 0.152\nsamples = 8\nvalue = 11.335'),
#  Text(0.2083635278571124, 0.15625, 'X[61] <= 1.661\nsquared_error = 0.01\nsamples = 2\nvalue = 10.698'),
#  Text(0.20802250735325462, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.8'),
#  Text(0.20870454836097022, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.2100686303764014, 0.15625, 'X[53] <= 1.18\nsquared_error = 0.019\nsamples = 6\nvalue = 11.548'),
#  Text(0.2093865893686858, 0.09375, 'X[61] <= 1.723\nsquared_error = 0.002\nsamples = 3\nvalue = 11.663'),
#  Text(0.209045568864828, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.691'),
#  Text(0.20972760987254357, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.21075067138411696, 0.09375, 'X[41] <= 0.346\nsquared_error = 0.01\nsamples = 3\nvalue = 11.432'),
#  Text(0.21040965088025917, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 11.503'),
#  Text(0.21109169188797478, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.20759623172343236, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.2228462423803231, 0.53125, 'X[49] <= 1.711\nsquared_error = 0.263\nsamples = 526\nvalue = 11.854'),
#  Text(0.22250522187646532, 0.46875, 'X[8] <= 1.162\nsquared_error = 0.252\nsamples = 525\nvalue = 11.849'),
#  Text(0.2153970757491794, 0.40625, 'X[60] <= -1.715\nsquared_error = 0.237\nsamples = 443\nvalue = 11.809'),
#  Text(0.21505605524532162, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 14.277'),
#  Text(0.21573809625303722, 0.34375, 'X[4] <= 0.305\nsquared_error = 0.224\nsamples = 442\nvalue = 11.803'),
#  Text(0.21399036617076603, 0.28125, 'X[20] <= 3.43\nsquared_error = 0.224\nsamples = 382\nvalue = 11.768'),
#  Text(0.21313781491112152, 0.21875, 'X[60] <= 0.403\nsquared_error = 0.208\nsamples = 380\nvalue = 11.76'),
#  Text(0.21245577390340595, 0.15625, 'X[43] <= 1.705\nsquared_error = 0.225\nsamples = 246\nvalue = 11.7'),
#  Text(0.21211475339954816, 0.09375, 'X[60] <= -0.866\nsquared_error = 0.208\nsamples = 245\nvalue = 11.709'),
#  Text(0.21177373289569035, 0.03125, 'squared_error = 0.158\nsamples = 105\nvalue = 11.846'),
#  Text(0.21245577390340595, 0.03125, 'squared_error = 0.222\nsamples = 140\nvalue = 11.606'),
#  Text(0.21279679440726373, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.21381985591883712, 0.15625, 'X[51] <= 1.671\nsquared_error = 0.157\nsamples = 134\nvalue = 11.869'),
#  Text(0.21347883541497933, 0.09375, 'X[44] <= 1.468\nsquared_error = 0.139\nsamples = 133\nvalue = 11.881'),
#  Text(0.21313781491112152, 0.03125, 'squared_error = 0.119\nsamples = 121\nvalue = 11.921'),
#  Text(0.21381985591883712, 0.03125, 'squared_error = 0.159\nsamples = 12\nvalue = 11.474'),
#  Text(0.2141608764226949, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.2148429174304105, 0.21875, 'X[49] <= 0.232\nsquared_error = 1.199\nsamples = 2\nvalue = 13.25'),
#  Text(0.21450189692655272, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 12.155'),
#  Text(0.2151839379342683, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 14.344'),
#  Text(0.2174858263353084, 0.28125, 'X[8] <= -0.3\nsquared_error = 0.161\nsamples = 60\nvalue = 12.029'),
#  Text(0.21620699944584168, 0.21875, 'X[50] <= 1.7\nsquared_error = 0.12\nsamples = 39\nvalue = 11.909'),
#  Text(0.2158659789419839, 0.15625, 'X[56] <= -0.993\nsquared_error = 0.091\nsamples = 38\nvalue = 11.938'),
#  Text(0.2151839379342683, 0.09375, 'X[58] <= -1.082\nsquared_error = 0.027\nsamples = 9\nvalue = 12.182'),
#  Text(0.2148429174304105, 0.03125, 'squared_error = 0.012\nsamples = 2\nvalue = 12.413'),
#  Text(0.21552495843812608, 0.03125, 'squared_error = 0.012\nsamples = 7\nvalue = 12.116'),
#  Text(0.21654801994969947, 0.09375, 'X[49] <= -1.148\nsquared_error = 0.086\nsamples = 29\nvalue = 11.862'),
#  Text(0.21620699944584168, 0.03125, 'squared_error = 0.055\nsamples = 3\nvalue = 12.346'),
#  Text(0.21688904045355728, 0.03125, 'squared_error = 0.06\nsamples = 26\nvalue = 11.807'),
#  Text(0.21654801994969947, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.21876465322477515, 0.21875, 'X[61] <= 0.954\nsquared_error = 0.161\nsamples = 21\nvalue = 12.252'),
#  Text(0.21757108146127285, 0.15625, 'X[43] <= -1.47\nsquared_error = 0.1\nsamples = 16\nvalue = 12.386'),
#  Text(0.21723006095741507, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.21791210196513067, 0.09375, 'X[57] <= -0.675\nsquared_error = 0.063\nsamples = 15\nvalue = 12.438'),
#  Text(0.21757108146127285, 0.03125, 'squared_error = 0.031\nsamples = 5\nvalue = 12.18'),
#  Text(0.21825312246898845, 0.03125, 'squared_error = 0.029\nsamples = 10\nvalue = 12.567'),
#  Text(0.2199582249882774, 0.15625, 'X[60] <= -0.902\nsquared_error = 0.116\nsamples = 5\nvalue = 11.823'),
#  Text(0.21927618398056184, 0.09375, 'X[52] <= 0.675\nsquared_error = 0.0\nsamples = 2\nvalue = 11.424'),
#  Text(0.21893516347670403, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.44'),
#  Text(0.21961720448441963, 0.03125, 'squared_error = -0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.220640265995993, 0.09375, 'X[43] <= 0.384\nsquared_error = 0.015\nsamples = 3\nvalue = 12.09'),
#  Text(0.22029924549213523, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.918'),
#  Text(0.2209812864998508, 0.03125, 'squared_error = 0.001\nsamples = 2\nvalue = 12.175'),
#  Text(0.22961336800375123, 0.40625, 'X[2] <= 1.109\nsquared_error = 0.277\nsamples = 82\nvalue = 12.067'),
#  Text(0.22682126262841554, 0.34375, 'X[45] <= 1.517\nsquared_error = 0.171\nsamples = 60\nvalue = 11.914'),
#  Text(0.22549980817596657, 0.28125, 'X[1] <= -0.458\nsquared_error = 0.134\nsamples = 58\nvalue = 11.878'),
#  Text(0.22387996078264205, 0.21875, 'X[45] <= 0.9\nsquared_error = 0.094\nsamples = 30\nvalue = 11.71'),
#  Text(0.22268638901913979, 0.15625, 'X[51] <= -0.771\nsquared_error = 0.077\nsamples = 26\nvalue = 11.651'),
#  Text(0.22200434801142419, 0.09375, 'X[55] <= 0.28\nsquared_error = 0.01\nsamples = 8\nvalue = 11.408'),
#  Text(0.2216633275075664, 0.03125, 'squared_error = 0.003\nsamples = 6\nvalue = 11.459'),
#  Text(0.22234536851528197, 0.03125, 'squared_error = 0.001\nsamples = 2\nvalue = 11.258'),
#  Text(0.22336843002685536, 0.09375, 'X[47] <= -1.168\nsquared_error = 0.069\nsamples = 18\nvalue = 11.759'),
#  Text(0.22302740952299757, 0.03125, 'squared_error = 0.01\nsamples = 4\nvalue = 11.467'),
#  Text(0.22370945053071317, 0.03125, 'squared_error = 0.054\nsamples = 14\nvalue = 11.842'),
#  Text(0.22507353254614434, 0.15625, 'X[45] <= 1.274\nsquared_error = 0.036\nsamples = 4\nvalue = 12.097'),
#  Text(0.22473251204228653, 0.09375, 'X[1] <= -0.486\nsquared_error = 0.012\nsamples = 3\nvalue = 12.192'),
#  Text(0.22439149153842874, 0.03125, 'squared_error = 0.0\nsamples = 2\nvalue = 12.114'),
#  Text(0.22507353254614434, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.346'),
#  Text(0.22541455305000213, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.2271196555692911, 0.21875, 'X[27] <= 0.755\nsquared_error = 0.115\nsamples = 28\nvalue = 12.058'),
#  Text(0.22643761456157552, 0.15625, 'X[46] <= 1.567\nsquared_error = 0.083\nsamples = 26\nvalue = 12.111'),
#  Text(0.22609659405771773, 0.09375, 'X[6] <= -0.401\nsquared_error = 0.052\nsamples = 25\nvalue = 12.075'),
#  Text(0.22575557355385992, 0.03125, 'squared_error = 0.033\nsamples = 3\nvalue = 11.657'),
#  Text(0.22643761456157552, 0.03125, 'squared_error = 0.027\nsamples = 22\nvalue = 12.132'),
#  Text(0.2267786350654333, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 13.017'),
#  Text(0.2278016965770067, 0.15625, 'X[62] <= 1.068\nsquared_error = 0.021\nsamples = 2\nvalue = 11.369'),
#  Text(0.2274606760731489, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.22814271708086448, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.22814271708086448, 0.28125, 'X[7] <= -1.977\nsquared_error = 0.12\nsamples = 2\nvalue = 12.958'),
#  Text(0.2278016965770067, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 12.612'),
#  Text(0.2284837375847223, 0.21875, 'squared_error = -0.0\nsamples = 1\nvalue = 13.305'),
#  Text(0.23240547337908693, 0.34375, 'X[50] <= -1.576\nsquared_error = 0.326\nsamples = 22\nvalue = 12.484'),
#  Text(0.23206445287522912, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 10.714'),
#  Text(0.23274649388294472, 0.28125, 'X[60] <= 1.464\nsquared_error = 0.186\nsamples = 21\nvalue = 12.568'),
#  Text(0.23087088111172685, 0.21875, 'X[55] <= -0.952\nsquared_error = 0.148\nsamples = 17\nvalue = 12.446'),
#  Text(0.22950679909629568, 0.15625, 'X[58] <= 0.047\nsquared_error = 0.084\nsamples = 5\nvalue = 12.823'),
#  Text(0.22882475808858008, 0.09375, 'X[61] <= 0.757\nsquared_error = 0.034\nsamples = 3\nvalue = 12.623'),
#  Text(0.2284837375847223, 0.03125, 'squared_error = 0.002\nsamples = 2\nvalue = 12.75'),
#  Text(0.22916577859243786, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.367'),
#  Text(0.23018884010401125, 0.09375, 'X[61] <= -0.69\nsquared_error = 0.009\nsamples = 2\nvalue = 13.123'),
#  Text(0.22984781960015346, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 13.028'),
#  Text(0.23052986060786904, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 13.218'),
#  Text(0.23223496312715802, 0.15625, 'X[51] <= 0.785\nsquared_error = 0.091\nsamples = 12\nvalue = 12.289'),
#  Text(0.23155292211944242, 0.09375, 'X[41] <= 0.346\nsquared_error = 0.037\nsamples = 9\nvalue = 12.154'),
#  Text(0.23121190161558464, 0.03125, 'squared_error = 0.016\nsamples = 6\nvalue = 12.266'),
#  Text(0.23189394262330024, 0.03125, 'squared_error = 0.002\nsamples = 3\nvalue = 11.929'),
#  Text(0.23291700413487362, 0.09375, 'X[45] <= -0.025\nsquared_error = 0.033\nsamples = 3\nvalue = 12.695'),
#  Text(0.2325759836310158, 0.03125, 'squared_error = 0.003\nsamples = 2\nvalue = 12.82'),
#  Text(0.2332580246387314, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.445'),
#  Text(0.23462210665416258, 0.21875, 'X[52] <= -0.483\nsquared_error = 0.015\nsamples = 4\nvalue = 13.087'),
#  Text(0.23394006564644698, 0.15625, 'X[61] <= 0.63\nsquared_error = 0.0\nsamples = 2\nvalue = 12.977'),
#  Text(0.2335990451425892, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.983'),
#  Text(0.2342810861503048, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 12.972'),
#  Text(0.23530414766187818, 0.15625, 'X[43] <= 0.967\nsquared_error = 0.006\nsamples = 2\nvalue = 13.197'),
#  Text(0.23496312715802037, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 13.122'),
#  Text(0.23564516816573597, 0.09375, 'squared_error = -0.0\nsamples = 1\nvalue = 13.271'),
#  Text(0.22318726288418092, 0.46875, 'squared_error = -0.0\nsamples = 1\nvalue = 14.344'),
#  Text(0.25782881836395416, 0.65625, 'X[60] <= -1.657\nsquared_error = 0.851\nsamples = 369\nvalue = 11.404'),
#  Text(0.243062364124643, 0.59375, 'X[58] <= 1.351\nsquared_error = 18.452\nsamples = 6\nvalue = 9.519'),
#  Text(0.2427213436207852, 0.53125, 'X[61] <= 0.732\nsquared_error = 0.395\nsamples = 5\nvalue = 11.423'),
#  Text(0.2420393026130696, 0.46875, 'X[60] <= -1.691\nsquared_error = 0.12\nsamples = 2\nvalue = 12.083'),
#  Text(0.24169828210921182, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 12.429'),
#  Text(0.2423803231169274, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.24340338462850078, 0.46875, 'X[44] <= 1.16\nsquared_error = 0.095\nsamples = 3\nvalue = 10.983'),
#  Text(0.243062364124643, 0.40625, 'X[56] <= -0.779\nsquared_error = 0.03\nsamples = 2\nvalue = 11.176'),
#  Text(0.2427213436207852, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.24340338462850078, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.2437444051323586, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.24340338462850078, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.27259527260326527, 0.59375, 'X[44] <= 1.679\nsquared_error = 0.5\nsamples = 363\nvalue = 11.435'),
#  Text(0.2669178140585703, 0.53125, 'X[22] <= 1.928\nsquared_error = 0.366\nsamples = 355\nvalue = 11.457'),
#  Text(0.2588025917558293, 0.46875, 'X[0] <= 0.607\nsquared_error = 0.343\nsamples = 345\nvalue = 11.478'),
#  Text(0.2512468562172301, 0.40625, 'X[61] <= -0.939\nsquared_error = 0.342\nsamples = 323\nvalue = 11.45'),
#  Text(0.24408542563621638, 0.34375, 'X[47] <= 0.022\nsquared_error = 0.301\nsamples = 75\nvalue = 11.653'),
#  Text(0.238884862952385, 0.28125, 'X[45] <= -1.26\nsquared_error = 0.361\nsamples = 40\nvalue = 11.809'),
#  Text(0.23666822967730936, 0.21875, 'X[1] <= -0.649\nsquared_error = 0.571\nsamples = 7\nvalue = 12.54'),
#  Text(0.23632720917345154, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 14.226'),
#  Text(0.23700925018116714, 0.15625, 'X[62] <= -0.662\nsquared_error = 0.113\nsamples = 6\nvalue = 12.258'),
#  Text(0.23632720917345154, 0.09375, 'X[22] <= 0.431\nsquared_error = 0.021\nsamples = 4\nvalue = 12.044'),
#  Text(0.23598618866959375, 0.03125, 'squared_error = 0.008\nsamples = 3\nvalue = 12.115'),
#  Text(0.23666822967730936, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.832'),
#  Text(0.23769129118888274, 0.09375, 'X[33] <= 1.428\nsquared_error = 0.022\nsamples = 2\nvalue = 12.687'),
#  Text(0.23735027068502493, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.835'),
#  Text(0.23803231169274053, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.539'),
#  ...]

# %% [markdown]
# To reduce the complexity of the tree, we **prune** the tree: we collapse its leaves, permitting bias to increase but forcing variance to decrease until the desired trade-off is achieved. In `rpart`, this is done by considering a modified loss function that takes into account the number of terminal nodes (i.e., the number of regions in which the original data was partitioned). Somewhat heuristically, if we denote tree predictions by $T(x)$ and its number of terminal nodes by  $|T|$, the modified regression problem can be written as:
#
#
#
#   $
#   \widehat{T} = \arg\min_{T} \sum_{i=1}^m \left( T(X_i) - Y_i \right)^2 + c_p |T|
#  $
#
#
# The complexity of the tree is controlled by the scalar parameter $c_p$, denoted as `cp` in `rpart`. For each value of $c_p$, we find the subtree that solves \@ref(eq:tree-cp). Large values of $c_p$ lead to aggressively pruned trees, which have more bias and less variance. Small values of $c_p$ allow for deeper trees whose predictions can vary more wildly. The plot below shows the cross-validated error (relative to a tree with only one node, which corresponds to predicting the sample mean everywhere) for trees obtained at different levels of  $c_p$. The bias-variance trade-off is optimized at the point at which the cross-validated error is minimized.

# %%
max_depth = []
mse_gini = []
for i in range(1,30):
    dtree = DecisionTreeRegressor( max_depth=i)
    dtree.fit(x_train, y_train)
    pred = dtree.predict(x_test)
    mse_gini.append(mean_squared_error(y_test, pred))
 ###
    max_depth.append(i)

d = pd.DataFrame({'acc_gini':pd.Series(mse_gini),'max_depth':pd.Series(max_depth)})
# visualizing changes in parameters
plt.figure(figsize=(18,5))
plt.plot('max_depth','acc_gini', data=d, label='mse')

plt.xlabel('max_depth')
plt.ylabel('mse')
plt.legend()

# %% [markdown]
# The following code retrieves the optimal parameter and prunes the tree. Here, instead of choosing the parameter that minimizes the mean-squared-error, we're following another common heuristic: we will choose the most regularized model whose error is within one standard error of the minimum error.

# %%
dt = DecisionTreeRegressor(ccp_alpha=0, max_depth= 4)
x_train, x_test, y_train, y_test = train_test_split(scale_X, Y, test_size=.3)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0, max_depth=4)

# %% [markdown]
# Plotting the pruned tree. See also the package [rpart.plot](http://www.milbo.org/rpart-plot/prp.pdf) for more advanced plotting capabilities.
# ```{r}

# %%
plt.figure(figsize=(18,5))
tree.plot_tree(dt)
# Out:
# [Text(0.5267857142857143, 0.9, 'X[22] <= 3.425\nsquared_error = 0.954\nsamples = 20108\nvalue = 11.811'),
#  Text(0.2857142857142857, 0.7, 'X[1] <= 0.003\nsquared_error = 0.752\nsamples = 19361\nvalue = 11.886'),
#  Text(0.14285714285714285, 0.5, 'X[3] <= -0.559\nsquared_error = 0.622\nsamples = 13871\nvalue = 11.687'),
#  Text(0.07142857142857142, 0.3, 'X[19] <= 0.789\nsquared_error = 0.635\nsamples = 5066\nvalue = 11.393'),
#  Text(0.03571428571428571, 0.1, 'squared_error = 0.609\nsamples = 2656\nvalue = 11.548'),
#  Text(0.10714285714285714, 0.1, 'squared_error = 0.609\nsamples = 2410\nvalue = 11.222'),
#  Text(0.21428571428571427, 0.3, 'X[1] <= -0.362\nsquared_error = 0.537\nsamples = 8805\nvalue = 11.855'),
#  Text(0.17857142857142858, 0.1, 'squared_error = 0.544\nsamples = 3179\nvalue = 11.675'),
#  Text(0.25, 0.1, 'squared_error = 0.504\nsamples = 5626\nvalue = 11.957'),
#  Text(0.42857142857142855, 0.5, 'X[3] <= 0.706\nsquared_error = 0.724\nsamples = 5490\nvalue = 12.39'),
#  Text(0.35714285714285715, 0.3, 'X[29] <= 0.044\nsquared_error = 0.617\nsamples = 2853\nvalue = 12.159'),
#  Text(0.32142857142857145, 0.1, 'squared_error = 1.038\nsamples = 727\nvalue = 11.838'),
#  Text(0.39285714285714285, 0.1, 'squared_error = 0.425\nsamples = 2126\nvalue = 12.269'),
#  Text(0.5, 0.3, 'X[1] <= 0.675\nsquared_error = 0.721\nsamples = 2637\nvalue = 12.64'),
#  Text(0.4642857142857143, 0.1, 'squared_error = 0.605\nsamples = 1627\nvalue = 12.46'),
#  Text(0.5357142857142857, 0.1, 'squared_error = 0.774\nsamples = 1010\nvalue = 12.928'),
#  Text(0.7678571428571429, 0.7, 'X[12] <= 5.214\nsquared_error = 2.232\nsamples = 747\nvalue = 9.857'),
#  Text(0.6785714285714286, 0.5, 'X[1] <= 6.34\nsquared_error = 2.456\nsamples = 439\nvalue = 9.344'),
#  Text(0.6428571428571429, 0.3, 'X[2] <= 0.555\nsquared_error = 2.262\nsamples = 438\nvalue = 9.366'),
#  Text(0.6071428571428571, 0.1, 'squared_error = 2.516\nsamples = 267\nvalue = 9.034'),
#  Text(0.6785714285714286, 0.1, 'squared_error = 1.423\nsamples = 171\nvalue = 9.884'),
#  Text(0.7142857142857143, 0.3, 'squared_error = -0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.8571428571428571, 0.5, 'X[44] <= 1.662\nsquared_error = 1.005\nsamples = 308\nvalue = 10.588'),
#  Text(0.7857142857142857, 0.3, 'X[0] <= -0.339\nsquared_error = 0.898\nsamples = 297\nvalue = 10.631'),
#  Text(0.75, 0.1, 'squared_error = 1.162\nsamples = 83\nvalue = 10.295'),
#  Text(0.8214285714285714, 0.1, 'squared_error = 0.735\nsamples = 214\nvalue = 10.761'),
#  Text(0.9285714285714286, 0.3, 'X[45] <= -1.514\nsquared_error = 2.497\nsamples = 11\nvalue = 9.431'),
#  Text(0.8928571428571429, 0.1, 'squared_error = 0.437\nsamples = 2\nvalue = 6.652'),
#  Text(0.9642857142857143, 0.1, 'squared_error = 0.858\nsamples = 9\nvalue = 10.049')]

# %% [markdown]
# Finally, here’s how to extract predictions and mse estimates from the pruned tree.

# %%
dt = DecisionTreeRegressor(ccp_alpha=0, max_depth= 4)
x_train, x_test, y_train, y_test = train_test_split(scale_X, Y, test_size=.3)
dt.fit(x_train,y_train)

y_pred = dt.predict(x_test)
mse = mean_squared_error(y_test, y_pred)

print("Tree MSE estimate:", mse)
# Out:
# Tree MSE estimate: 0.6917955471703022

# %% [markdown]
# It’s often said that trees are "interpretable." To some extent, that’s true – we can look at the tree and clearly visualize the mapping from inputs to prediction. This can be important in settings in which conveying how one got to a prediction is important. For example, if a decision tree were to be used for credit scoring, it would be easy to explain to a client how their credit was scored.
#
# Beyond that, however, there are several reasons for not interpreting the obtained decision tree further. First, even though a tree may have used a particular variable for a split, that does not mean that it’s indeed an important variable: if two covariates are highly correlated, the tree may split on one variable but not the other, and there’s no guarantee which variables are relevant in the underlying data-generating process.
#
# Similar to what we did for Lasso above, we can estimate the average value of each covariate per leaf. Although results are noisier here because there are many leaves, we see somewhat similar trends in that houses with higher predictions are also correlated with more bedrooms, bathrooms and room sizes.

# %%
pd.Series(y_pred).unique().shape
# Out:
# (14,)

# %% [markdown]
# Finally, as we did in the linear model case, we can use the same code for an annotated version of the same information. Again, we ordered the rows in decreasing order based on an estimate of the relative variance "explained" by leaf membership: $Var(E[X_i|L_i]) / Var(X_i)$, where $L_i$ represents the leaf.

# %% [markdown]
# ### Forest

# %% [markdown]
# Forests are a type of **ensemble** estimators: they aggregate information about many decision trees to compute a new estimate that typically has much smaller variance.
#
# At a high level, the process of fitting a (regression) forest consists of fitting many decision trees, each on a different subsample of the data. The forest prediction for a particular point $x$ is the average of all tree predictions for that point.
#
# One interesting aspect of forests and many other ensemble methods is that cross-validation can be built into the algorithm itself. Since each tree only uses a subset of the data, the remaining subset is effectively a test set for that tree. We call these observations **out-of-bag** (there were not in the “bag” of training observations). They can be used to evaluate the performance of that tree, and the average of out-of-bag evaluations is evidence of the performance of the forest itself.
#
# For the example below, we’ll use the regression_forest function of the `R` package `grf`. The particular forest implementation in `grf` has interesting properties that are absent from most other packages. For example, trees are build using a certain sample-splitting scheme that ensures that predictions are approximately unbiased and normally distributed for large samples, which in turn allows us to compute valid confidence intervals around those predictions. We’ll have more to say about the importance of these features when we talk about causal estimates in future chapters. See also the grf website for more information.

# %%
from sklearn.ensemble import RandomForestRegressor


forest = RandomForestRegressor(n_estimators=200)
x_train, x_test, y_train, y_test = train_test_split(scale_X, Y, test_size=.3)
forest.fit(x_train, y_train)
# Retrieving forest predictions
y_pred = forest.predict(x_test)

# Evaluation
mse = mean_squared_error(y_test, y_pred)

print("Forest MSE (out-of-bag):", mse)
# Out:
# Forest MSE (out-of-bag): 0.614364560942982

# %% [markdown]
# The function `variable_importance` computes a simple weighted sum of how many times each feature was split on at each depth across the trees.

# %%
plt.figure(figsize=(20,10))
sorted_idx = forest.feature_importances_.argsort()
plt.barh(X.columns[sorted_idx], forest.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
X.columns.shape
# Out:
# (63,)

# %% [markdown]
# All the caveats about interpretation that we mentioned above apply in a similar to forest output.

# %% [markdown]
# ## Further reading

# %% [markdown]
# In this tutorial we briefly reviewed some key concepts that we recur later in this tutorial. For readers who are entirely new to this field or interested in learning about it more depth, the first few chapters of the following textbook are an acccessible introduction:
#
# James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An introduction to statistical learning (Vol. 112, p. 18). New York: springer. Available for free at [the authors’ website](https://www.statlearning.com/).
#
# Some of the discussion in the Lasso section in particular was drawn from [Mullainathan and Spiess (JEP, 2017)](https://www.aeaweb.org/articles?id=10.1257/jep.31.2.87), which contains a good discussion of the interpretability issues discussed here.
#
# There has been a good deal of research on inference in high-dimensional models, Although we won’t be covering in depth it in this tutorial, we refer readers to [Belloni, Chernozhukov and Hansen (JEP, 2014)](http://www.mit.edu/~vchern/papers/JEP.pdf). Also check out the related `R` package [`hdm`](https://cran.r-project.org/web/packages/hdm/hdm.pdf), developed by the same authors, along with Philipp Bach and Martin Spindler.
